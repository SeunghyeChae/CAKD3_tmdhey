# %%
import pandas as pd
import numpy as np

baby = pd.read_excel('dataset/전국어린이보호구역표준데이터-20210801.xls')

baby.columns = baby.iloc[0]
baby = baby.iloc[1:]

# %%
asan = pd.read_csv('dataset/아산시 어린이보호구역.csv',encoding='cp949')
asan
# Out:
#     시설종류             대상시설명                       소재지도로명주소  소재지지번주소         위도  \
# 0   어린이집           굿모닝어린이집    충청남도 아산시 권곡로14번길 7-14 (권곡동)      NaN  36.792569
# 1   어린이집           대통령어린이집         충청남도 아산시 배방읍 온천대로 2358      NaN  36.780963
# 2   어린이집        둔포아이조아어린이집   충청남도 아산시 둔포면 아산호로 1216 (송용리)      NaN  36.926282
# 3   어린이집            리라어린이집  충청남도 아산시 온주길16번길 888-26 (장존동)      NaN  36.756862
# 4   어린이집            비버어린이집          충청남도 아산시 배방읍 북수로 87-8      NaN  36.774388
# ..   ...               ...                            ...      ...        ...
# 82  초등학교            충무초등학교            충청남도 아산시 문화로 271-45      NaN  36.790722
# 83  초등학교  탕정초등학교(병설유치원 포함)          충청남도 아산시 탕정면 탕정면로 105      NaN  36.802035
# 84  초등학교            퐁기초등학교               충청남도 아산시 남부로 351      NaN  36.774711
# 85  특수학교              성심학교          충청남도 아산시 선장면 아산만로 368      NaN  36.776890
# 86  특수학교           충남다사랑학교        충청남도 아산시 둔포면 아산밸리동로 247      NaN  36.916698
#
#             경도      관리기관명 관할경찰서명 CCTV설치여부  CCTV설치대수  보호구역도로폭     데이터기준일자
# 0   127.011036  충청남도 아산시청  아산경찰서        N         0        5  2020-09-01
# 1   127.093948  충청남도 아산시청  아산경찰서        Y         1        7  2020-09-01
# 2   127.034098  충청남도 아산시청  아산경찰서        Y         1        7  2020-09-01
# 3   127.019334  충청남도 아산시청  아산경찰서        Y         1        5  2020-09-01
# 4   127.070905  충청남도 아산시청  아산경찰서        Y         2        5  2020-09-01
# ..         ...        ...    ...      ...       ...      ...         ...
# 82  127.020292  충청남도 아산시청  아산경찰서        Y         3       12  2020-09-01
# 83  127.066138  충청남도 아산시청  아산경찰서        Y         4        7  2020-09-01
# 84  127.018461  충청남도 아산시청  아산경찰서        Y         1        7  2020-09-01
# 85  126.863149  충청남도 아산시청  아산경찰서        Y         1        7  2020-09-01
# 86  127.066588  충청남도 아산시청  아산경찰서        Y         1        7  2020-09-01
#
# [87 rows x 12 columns]

# %%
import requests
import json
import numpy as np


addrs = list(asan['소재지도로명주소'])
locations = []


for addr in addrs:
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query={}'.format(addr)
    headers = {
        "Authorization" : "KakaoAK ec276bf4e2dcd1c5055b2da48ef1b6f7"}
    place = requests.get(url, headers = headers).json()['documents']
    locations.append(place)
    
city = []
town = []

for i in range(len(locations)):
    
    try:
        city.append(locations[i][0].get('address').get('region_2depth_name'))
        town.append(locations[i][0].get('address').get('region_3depth_name'))
        
    except IndexError:
        print(i,'번째 주소 못가져옴',end ='')
        print()
        city.append('없음')
        town.append('없음')
        
    except AttributeError:
        city.append(locations[i][0].get('address').get('region_2depth_name'))
        town.append(locatuons[i][0].get('address').get('region_3depth_name'))


city_town = np.array([city,town]).T
df_temp = pd.DataFrame(city_town, columns = ['2', '3'])
# asan['소재지지번주소'] = df_temp[['3']]
asan['소재지지번주소'] = df_temp[['3']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-51c7fd8be12c> in <module>
#       4
#       5
# ----> 6 addrs = list(asan['소재지도로명주소'])
#       7 locations = []
#       8
#
# NameError: name 'asan' is not defined

# %%
asan.소재지도로명주소.unique()

# %%
def dong(x):
    import re

    p = re.compile('[가-힣]\S.[동읍리면]')

    r = p.findall(x)
    
    return ''.join(r)
asan['소재지지번주소'] = asan.소재지지번주소.apply(dong)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-065fe698e0ea> in <module>
#       7
#       8     return ''.join(r)
# ----> 9 asan['소재지지번주소'] = asan.소재지지번주소.apply(dong)
#
# NameError: name 'asan' is not defined

# %%
asan
# Out:
#     시설종류             대상시설명                       소재지도로명주소 소재지지번주소         위도  \
# 0   어린이집           굿모닝어린이집    충청남도 아산시 권곡로14번길 7-14 (권곡동)     권곡동  36.792569
# 1   어린이집           대통령어린이집         충청남도 아산시 배방읍 온천대로 2358     배방읍  36.780963
# 2   어린이집        둔포아이조아어린이집   충청남도 아산시 둔포면 아산호로 1216 (송용리)          36.926282
# 3   어린이집            리라어린이집  충청남도 아산시 온주길16번길 888-26 (장존동)     장존동  36.756862
# 4   어린이집            비버어린이집          충청남도 아산시 배방읍 북수로 87-8     배방읍  36.774388
# ..   ...               ...                            ...     ...        ...
# 82  초등학교            충무초등학교            충청남도 아산시 문화로 271-45     권곡동  36.790722
# 83  초등학교  탕정초등학교(병설유치원 포함)          충청남도 아산시 탕정면 탕정면로 105          36.802035
# 84  초등학교            퐁기초등학교               충청남도 아산시 남부로 351     풍기동  36.774711
# 85  특수학교              성심학교          충청남도 아산시 선장면 아산만로 368          36.776890
# 86  특수학교           충남다사랑학교        충청남도 아산시 둔포면 아산밸리동로 247          36.916698
#
#             경도      관리기관명 관할경찰서명 CCTV설치여부  CCTV설치대수  보호구역도로폭     데이터기준일자
# 0   127.011036  충청남도 아산시청  아산경찰서        N         0        5  2020-09-01
# 1   127.093948  충청남도 아산시청  아산경찰서        Y         1        7  2020-09-01
# 2   127.034098  충청남도 아산시청  아산경찰서        Y         1        7  2020-09-01
# 3   127.019334  충청남도 아산시청  아산경찰서        Y         1        5  2020-09-01
# 4   127.070905  충청남도 아산시청  아산경찰서        Y         2        5  2020-09-01
# ..         ...        ...    ...      ...       ...      ...         ...
# 82  127.020292  충청남도 아산시청  아산경찰서        Y         3       12  2020-09-01
# 83  127.066138  충청남도 아산시청  아산경찰서        Y         4        7  2020-09-01
# 84  127.018461  충청남도 아산시청  아산경찰서        Y         1        7  2020-09-01
# 85  126.863149  충청남도 아산시청  아산경찰서        Y         1        7  2020-09-01
# 86  127.066588  충청남도 아산시청  아산경찰서        Y         1        7  2020-09-01
#
# [87 rows x 12 columns]

# %%
asan.to_csv('dataset/ana.csv')
