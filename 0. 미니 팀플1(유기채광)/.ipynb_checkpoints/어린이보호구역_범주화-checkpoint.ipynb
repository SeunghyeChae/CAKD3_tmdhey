# %%
import pandas as pd

df1= pd.read_csv('dataset/어린이보호구역 위치도.csv')

df2= pd.read_excel('dataset/전국어린이보호구역표준데이터-20210801.xls')

# %%
df2 = df2.rename(columns=df2.iloc[0])
df2= df2.drop(df2.index[0])
df2
# Out:
#        시설종류       대상시설명                            소재지도로명주소  \
# 1      초등학교      오덕초등학교                  강원도 철원군 동송읍 오덕로159
# 2      초등학교      문혜초등학교                 강원도 철원군 갈말읍 태봉로1556
# 3      어린이집     로이스어린이집               대구광역시 달서구 진천로3길 85-11
# 4      어린이집      예원어린이집              대구광역시 달서구 월곡로47안길 33-7
# 5      어린이집      해뜰어린이집              대구광역시 달서구 월곡로47안길 33-4
# ...     ...         ...                                 ...
# 17572  어린이집    정인아트어린이집               인천광역시 계양구 계산천서로24번길12
# 17573  어린이집      하늘어린이집              인천광역시 계양구 경명대로1078번길14
# 17574  어린이집  태양창의아트어린이집             인천광역시 계양구 주부토로529번길13-1
# 17575  어린이집   귤현꿈나무어린이집                    인천광역시 계양구 귤현길 12
# 17576   유치원      예지슬유치원  경기도 고양시 일산서구 장자길 74-1 (덕이동) 예지슬유치원
#
#                       소재지지번주소             위도              경도       관리기관명  \
# 1         강원도 철원군 동송읍 오덕리 산23  38.2229984579      127.232171     강원도 철원군
# 2      강원도 철원군 갈말읍 문혜리 1099-4  38.1868442263  127.3180714284     강원도 철원군
# 3        대구광역시 달서구 진천동 470-23    35.80974735     128.5214745  대구광역시 달서구청
# 4           대구광역시 달서구 상인동 588     35.8149995     128.5403876  대구광역시 달서구청
# 5           대구광역시 달서구 상인동 588    35.81479254     128.5403087  대구광역시 달서구청
# ...                       ...            ...             ...         ...
# 17572                     NaN    37.54098251      126.719641  인천광역시 계양구청
# 17573                     NaN    37.54201132     126.7265184  인천광역시 계양구청
# 17574                     NaN    37.54129106      126.726734  인천광역시 계양구청
# 17575                     NaN    37.56824928     126.7480151  인천광역시 계양구청
# 17576  경기도 고양시 일산서구 덕이동 774-4  37.6984177295     126.7453033     경기도 고양시
#
#             관할경찰서명 CCTV설치여부 CCTV설치대수 보호구역도로폭     데이터기준일자   제공기관코드      제공기관명
# 1            철원경찰서        Y        1       6  2020-08-26  4300000    강원도 철원군
# 2            철원경찰서        Y        1       6  2020-08-26  4300000    강원도 철원군
# 3      대구광역시 달서경찰서        Y        1       6  2021-03-15  3470000  대구광역시 달서구
# 4      대구광역시 달서경찰서        Y        1       6  2021-03-15  3470000  대구광역시 달서구
# 5      대구광역시 달서경찰서        Y        1       6  2021-03-15  3470000  대구광역시 달서구
# ...            ...      ...      ...     ...         ...      ...        ...
# 17572  인천광역시 계양경찰서        Y      NaN     NaN  2021-06-07  3550000  인천광역시 계양구
# 17573  인천광역시 계양경찰서        Y      NaN     NaN  2021-06-07  3550000  인천광역시 계양구
# 17574  인천광역시 계양경찰서        Y      NaN     NaN  2021-06-07  3550000  인천광역시 계양구
# 17575  인천광역시 계양경찰서        Y      NaN     NaN  2021-06-07  3550000  인천광역시 계양구
# 17576         일산서부        N      NaN    3~40  2021-07-01  3940000    경기도 고양시
#
# [17576 rows x 14 columns]

# %%
# pd.set_option('display.max_rows',500)
# df2.제공기관명.value_counts()

# %%
# seoul_df1 = df1.loc[df1.iloc[:,8].str.contains('서울특별시',na=False)]
# seoul_df1

# %%
seoul_df2 = df2.loc[df2.loc[:,'제공기관명'].str.contains('서울',na=False)]
seoul_df2
# Out:
#        시설종류        대상시설명               소재지도로명주소                소재지지번주소  \
# 432    초등학교  청파초교(병설유치원)     서울특벽시 용산구 효창원로 228   서울특별시 용산구 청파동2가 1-42
# 433    어린이집    강동복지관어린이집    서울특별시 강동구 진황도로23길 7     서울특별시 강동구 천호3동 555
# 434    어린이집    올리브나무어린이집  서울특별시 강동구 양재대로134길 41  서울특별시 강동구 명일1동 338-19
# 435    어린이집    자이젠킨더어린이집  서울특별시 강동구 천호대로199길 25     서울특별시 강동구 길동 123-2
# 436    어린이집    강동무지개어린이집  서울특별시 강동구 양재대로125길 30    서울특별시 강동구 천호동 43-22
# ...     ...          ...                    ...                    ...
# 17531   유치원      방배병설유치원  서울특별시 서초구 방배중앙로13길 26    서울특별시 서초구 방배동 861-1
# 17532   유치원       새성민유치원      서울특별시 서초구 효령로 110    서울특별시 서초구 방배동 981-2
# 17533   유치원        새순유치원   서울특별시 서초구 서초대로15길 57   서울특별시 서초구 방배동 831-12
# 17534   유치원      서래병설유치원      서울특별시 서초구 방배로 260     서울특별시 서초구 방배본동 771
# 17535   유치원     서울청계숲유치원   서울특별시 서초구 청계산로11길 14      서울특별시 서초구 신원동 247
#
#                   위도              경도       관리기관명 관할경찰서명 CCTV설치여부 CCTV설치대수  \
# 432    37.5473030994  126.9635440384        용산구청  용산경찰서        Y      NaN
# 433    37.5400428356     127.1297892  서울특별시 강동구청  강동경찰서        Y        1
# 434       37.5478059     127.1459154  서울특별시 강동구청  강동경찰서        Y        1
# 435       37.5377155     127.1478568  서울특별시 강동구청  강동경찰서        Y        1
# 436    37.5446048382     127.1406641  서울특별시 강동구청  강동경찰서        Y        1
# ...              ...             ...         ...    ...      ...      ...
# 17531    37.48676419     126.9871372     서울시 서초구  방배경찰서        Y        1
# 17532     37.4806567     126.9961191     서울시 서초구  방배경찰서        Y        1
# 17533    37.48906371     126.9885796     서울시 서초구  방배경찰서        Y        1
# 17534    37.49640526     126.9901572     서울시 서초구  방배경찰서        Y        1
# 17535      37.447737     127.0577441     서울시 서초구  서초경찰서        Y        1
#
#       보호구역도로폭     데이터기준일자   제공기관코드      제공기관명
# 432      4~12  2020-02-18  3020000  서울특별시 용산구
# 433         6  2020-09-11  3240000  서울특별시 강동구
# 434         6  2020-09-11  3240000  서울특별시 강동구
# 435         5  2020-09-11  3240000  서울특별시 강동구
# 436         6  2020-09-11  3240000  서울특별시 강동구
# ...       ...         ...      ...        ...
# 17531       1  2020-07-01  3210000  서울특별시 서초구
# 17532       1  2020-07-01  3210000  서울특별시 서초구
# 17533       1  2020-07-01  3210000  서울특별시 서초구
# 17534       1  2020-07-01  3210000  서울특별시 서초구
# 17535       1  2020-07-01  3210000  서울특별시 서초구
#
# [1646 rows x 14 columns]

# %%
seoul_df2['제공기관명'].value_counts()
# Out:
# 서울특별시 노원구     106
# 서울특별시 성북구     102
# 서울특별시 강남구     101
# 서울특별시 강동구      90
# 서울특별시 송파구      90
# 서울특별시 강서구      88
# 서울특별시 광진구      77
# 서울특별시 은평구      76
# 서울특별시 동대문구     74
# 서울특별시 서초구      73
# 서울특별시 도봉구      70
# 서울특별시 양천구      68
# 서울특별시 관악구      66
# 서울특별시 영등포구     66
# 서울특별시 동작구      65
# 서울특별시 구로구      62
# 서울특별시 마포구      52
# 서울특별시 성동구      51
# 서울특별시 금천구      43
# 서울특별시 중랑구      42
# 서울특별시 종로구      40
# 서울특별시 서대문구     40
# 서울특별시 강북구      38
# 서울특별시 중구       33
# 서울특별시 용산구      33
# Name: 제공기관명, dtype: int64

# %%
df2= seoul_df2.drop(['소재지지번주소','관리기관명','보호구역도로폭'], axis=1)
df2.head()
# Out:
#      시설종류        대상시설명               소재지도로명주소             위도              경도  \
# 432  초등학교  청파초교(병설유치원)     서울특벽시 용산구 효창원로 228  37.5473030994  126.9635440384
# 433  어린이집    강동복지관어린이집    서울특별시 강동구 진황도로23길 7  37.5400428356     127.1297892
# 434  어린이집    올리브나무어린이집  서울특별시 강동구 양재대로134길 41     37.5478059     127.1459154
# 435  어린이집    자이젠킨더어린이집  서울특별시 강동구 천호대로199길 25     37.5377155     127.1478568
# 436  어린이집    강동무지개어린이집  서울특별시 강동구 양재대로125길 30  37.5446048382     127.1406641
#
#     관할경찰서명 CCTV설치여부 CCTV설치대수     데이터기준일자   제공기관코드      제공기관명
# 432  용산경찰서        Y      NaN  2020-02-18  3020000  서울특별시 용산구
# 433  강동경찰서        Y        1  2020-09-11  3240000  서울특별시 강동구
# 434  강동경찰서        Y        1  2020-09-11  3240000  서울특별시 강동구
# 435  강동경찰서        Y        1  2020-09-11  3240000  서울특별시 강동구
# 436  강동경찰서        Y        1  2020-09-11  3240000  서울특별시 강동구

# %%
df2[df2.위도.isnull()]
# Out:
#        시설종류   대상시설명                            소재지도로명주소   위도          경도  \
# 11677   유치원   우현유치원  서울특별시 강서구 강서로 348 상가 2동 201호(우장산동)  NaN         NaN
# 14720  초등학교  신자초등학교             서울특별시 광진구 자양동 뚝섬로46길 64  NaN  127.073328
#
#       관할경찰서명 CCTV설치여부 CCTV설치대수     데이터기준일자   제공기관코드      제공기관명
# 11677  강서경찰서        N      NaN  2021-02-15  3150000  서울특별시 강서구
# 14720  광진경찰서        Y        7  2020-12-23  3040000  서울특별시 광진구

# %%
df2.위도.fillna(37.530289,inplace=True)

# %%
df2[df2.경도.isnull()]
# Out:
#       시설종류        대상시설명                            소재지도로명주소         위도   경도  \
# 1935   유치원  동원초등학교병설유치원         서울특별시 중랑구 서울특별시 중랑구 송림길 114  37.594978  NaN
# 7521   유치원      신자병설유치원             서울특별시 광진구 자양동 뚝섬로46길 64  37.530017  NaN
# 11677  유치원        우현유치원  서울특별시 강서구 강서로 348 상가 2동 201호(우장산동)  37.530289  NaN
#
#       관할경찰서명 CCTV설치여부 CCTV설치대수     데이터기준일자   제공기관코드      제공기관명
# 1935   중랑경찰서        Y      NaN  2020-12-08  3060000  서울특별시 중랑구
# 7521   광진경찰서        Y        1  2020-12-23  3040000  서울특별시 광진구
# 11677  강서경찰서        N      NaN  2021-02-15  3150000  서울특별시 강서구

# %%
df2.loc[1935,'경도']= 127.104917
df2.loc[7521,'경도']= 127.075449

# %%
# df2.iloc[1935,4]=df2.iloc[1935,4].fillna(127.104917)
# df2.iloc[7521,4]=df2.iloc[7521,4].fillna(127.075449)

# %%
# df2.loc['서울특별시 중랑구','경도'].fillna(127.104917,inplace=True)
# df2.loc['서울특별시 광진구','경도'].fillna(127.075449,inplace=True)

# %%
df2.isnull().sum()
# Out:
# 시설종류          0
# 대상시설명         0
# 소재지도로명주소      1
# 위도            0
# 경도            1
# 관할경찰서명        0
# CCTV설치여부      0
# CCTV설치대수    185
# 데이터기준일자       0
# 제공기관코드        0
# 제공기관명         0
# dtype: int64

# %%
seoul_df2['제공기관명'].value_counts()
# Out:
# 서울특별시 노원구     106
# 서울특별시 성북구     102
# 서울특별시 강남구     101
# 서울특별시 강동구      90
# 서울특별시 송파구      90
# 서울특별시 강서구      88
# 서울특별시 광진구      77
# 서울특별시 은평구      76
# 서울특별시 동대문구     74
# 서울특별시 서초구      73
# 서울특별시 도봉구      70
# 서울특별시 양천구      68
# 서울특별시 관악구      66
# 서울특별시 영등포구     66
# 서울특별시 동작구      65
# 서울특별시 구로구      62
# 서울특별시 마포구      52
# 서울특별시 성동구      51
# 서울특별시 금천구      43
# 서울특별시 중랑구      42
# 서울특별시 종로구      40
# 서울특별시 서대문구     40
# 서울특별시 강북구      38
# 서울특별시 중구       33
# 서울특별시 용산구      33
# Name: 제공기관명, dtype: int64

# %%
# a = df2['제공기관명'] == '서울특별시 노원구'
# nowon = df2[a]

# b = df2['제공기관명'] == '서울특별시 성북구'
# Seongbuk = df2[b]

# c = df2['제공기관명'] == '서울특별시 송파구'
# Songpa = df2[c]

# d = df2['제공기관명'] == '서울특별시 강동구'
# gangdong = df2[d]

# e = df2['제공기관명'] == '서울특별시 광진구'
# gwangjin = df2[e]

# f = df2['제공기관명'] == '서울특별시 동대문구'
# dongdaemun = df2[f]

# g = df2['제공기관명'] == '서울특별시 서초구'
# seocho = df2[g]

# h = df2['제공기관명'] == '서울특별시 양천구'
# yangcheon = df2[h]

# i = df2['제공기관명'] == '서울특별시 영등포구'
# yeongdeungpo = df2[i]

# j = df2['제공기관명'] == '서울특별시 동작구'
# dongjak = df2[j]

# k = df2['제공기관명'] == '서울특별시 마포구'
# mapo = df2[k]

# l = df2['제공기관명'] == '서울특별시 성동구'
# seongdong = df2[l]

# m = df2['제공기관명'] == '서울특별시 금천구'
# geumcheon = df2[m]

# n = df2['제공기관명'] == '서울특별시 중랑구'
# jungnang = df2[n]

# o = df2['제공기관명'] == '서울특별시 종로구'
# jongno = df2[o]

# p = df2['제공기관명'] == '서울특별시 서대문구'
# seodaemun = df2[p]

# q = df2['제공기관명'] == '서울특별시 강북구'
# gangbuk = df2[q]

# r = df2['제공기관명'] == '서울특별시 중구'
# junggu = df2[r]

# s = df2['제공기관명'] == '서울특별시 관악구'
# gwanak = df2[s]

# t = df2['제공기관명'] == '서울특별시 용산구'
# yongsan = df2[t]

# %%
# ## gu_cat 만들기 ~!

# %%
# seoul_df2['제공기관명']= seoul_df2['제공기관명'].apply(lambda x: x.strip(' 서울특별시'))
# seoul_df2

name_split= df2['제공기관명'].str.split(' ')
df2['제공기관명']= name_split.str.get(1)

df2
# Out:
#        시설종류        대상시설명               소재지도로명주소             위도  \
# 432    초등학교  청파초교(병설유치원)     서울특벽시 용산구 효창원로 228  37.5473030994
# 433    어린이집    강동복지관어린이집    서울특별시 강동구 진황도로23길 7  37.5400428356
# 434    어린이집    올리브나무어린이집  서울특별시 강동구 양재대로134길 41     37.5478059
# 435    어린이집    자이젠킨더어린이집  서울특별시 강동구 천호대로199길 25     37.5377155
# 436    어린이집    강동무지개어린이집  서울특별시 강동구 양재대로125길 30  37.5446048382
# ...     ...          ...                    ...            ...
# 17531   유치원      방배병설유치원  서울특별시 서초구 방배중앙로13길 26    37.48676419
# 17532   유치원       새성민유치원      서울특별시 서초구 효령로 110     37.4806567
# 17533   유치원        새순유치원   서울특별시 서초구 서초대로15길 57    37.48906371
# 17534   유치원      서래병설유치원      서울특별시 서초구 방배로 260    37.49640526
# 17535   유치원     서울청계숲유치원   서울특별시 서초구 청계산로11길 14      37.447737
#
#                    경도 관할경찰서명 CCTV설치여부 CCTV설치대수     데이터기준일자   제공기관코드 제공기관명
# 432    126.9635440384  용산경찰서        Y      NaN  2020-02-18  3020000   용산구
# 433       127.1297892  강동경찰서        Y        1  2020-09-11  3240000   강동구
# 434       127.1459154  강동경찰서        Y        1  2020-09-11  3240000   강동구
# 435       127.1478568  강동경찰서        Y        1  2020-09-11  3240000   강동구
# 436       127.1406641  강동경찰서        Y        1  2020-09-11  3240000   강동구
# ...               ...    ...      ...      ...         ...      ...   ...
# 17531     126.9871372  방배경찰서        Y        1  2020-07-01  3210000   서초구
# 17532     126.9961191  방배경찰서        Y        1  2020-07-01  3210000   서초구
# 17533     126.9885796  방배경찰서        Y        1  2020-07-01  3210000   서초구
# 17534     126.9901572  방배경찰서        Y        1  2020-07-01  3210000   서초구
# 17535     127.0577441  서초경찰서        Y        1  2020-07-01  3210000   서초구
#
# [1646 rows x 11 columns]

# %%
seoul_count = pd.pivot_table(df2,index='제공기관명',columns='시설종류',values='대상시설명',aggfunc='count',fill_value=0)
seoul_count
# Out:
# 시설종류   국제학교  대안학교  어린이집  외국인교육기관  외국인학교  유치원  초등학교  특수학교  학원
# 제공기관명
# 강남구       0     0    45        0      0   21    32     3   0
# 강동구       0     0    29        0      0   30    28     2   1
# 강북구       0     0    14        0      0    6    15     3   0
# 강서구       0     0    21        0      0   29    35     1   2
# 관악구       0     0    13        0      0   29    22     2   0
# 광진구       0     0    22        0      2   30    22     1   0
# 구로구       0     1    15        0      0   18    26     2   0
# 금천구       0     0    21        0      0    4    18     0   0
# 노원구       0     0    14        0      0   48    42     2   0
# 도봉구       0     0    23        0      0   23    23     1   0
# 동대문구      0     0    35        0      0   19    20     0   0
# 동작구       0     0    17        0      0   21    21     1   5
# 마포구       0     0    10        0      0   19    23     0   0
# 서대문구      0     0     4        0      0   16    19     1   0
# 서초구       0     0    32        0      0   16    24     1   0
# 성동구       0     0    10        0      0   20    21     0   0
# 성북구       0     0    31        0      0   41    29     1   0
# 송파구       0     0    23        0      0   26    40     1   0
# 양천구       0     0    24        0      0   12    29     0   3
# 영등포구      0     0    15        0      0   28    23     0   0
# 용산구       1     0     7        1      0    9    15     0   0
# 은평구       0     0    15        0      0   23    37     1   0
# 종로구       1     0    16        0      0    9    12     2   0
# 중구        0     0    15        0      0    7    11     0   0
# 중랑구       0     0     6        0      0   13    23     0   0

# %%
seoul_count.to_csv('전처리완료dataset/어린이보호구역데이터.csv')

# %%
sc= seoul_count.sum(axis=1)

# %%
df= pd.DataFrame(sc)
df

df.reset_index()
# Out:
#    제공기관명    0
# 0    강남구  101
# 1    강동구   90
# 2    강북구   38
# 3    강서구   88
# 4    관악구   66
# 5    광진구   77
# 6    구로구   62
# 7    금천구   43
# 8    노원구  106
# 9    도봉구   70
# 10  동대문구   74
# 11   동작구   65
# 12   마포구   52
# 13  서대문구   40
# 14   서초구   73
# 15   성동구   51
# 16   성북구  102
# 17   송파구   90
# 18   양천구   68
# 19  영등포구   66
# 20   용산구   33
# 21   은평구   76
# 22   종로구   40
# 23    중구   33
# 24   중랑구   42

# %%
df.index
# Out:
# Index(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구',
#        '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구',
#        '용산구', '은평구', '종로구', '중구', '중랑구'],
#       dtype='object', name='제공기관명')
