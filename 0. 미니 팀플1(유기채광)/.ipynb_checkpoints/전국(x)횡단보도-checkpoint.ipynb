# %%
import pandas as pd

data = pd.read_excel('dataset/전국횡단보도표준데이터-20210801.xls',index_col=0)

data.head()
# Out:
#      Unnamed: 1 Unnamed: 2 Unnamed: 3               Unnamed: 4 Unnamed: 5  \
# 시도명        시군구명        도로명   소재지도로명주소                  소재지지번주소   횡단보도관리번호
# 경상남도        양산시       양산대로        NaN  경상남도 양산시 하북면 용연리 1089-8   양산신-1001
# 경상남도        양산시       양산대로        NaN  경상남도 양산시 하북면 용연리 1012-4   양산신-1002
# 경상남도        양산시       양산대로        NaN  경상남도 양산시 하북면 용연리 1145-3   양산신-1005
# 경상남도        양산시       양산대로        NaN  경상남도 양산시 하북면 백록리 1040-1   양산신-1007
#
#      Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ...  \
# 시도명      횡단보도종류  자전거횡단도겸용여부    고원식적용여부         위도          경도  ...
# 경상남도          1           N          N  35.431776  129.067611  ...
# 경상남도          1           N          N  35.433768  129.068334  ...
# 경상남도          1           N          N  35.442733  129.072161  ...
# 경상남도          1           N          N  35.455274  129.076969  ...
#
#      Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23  \
# ...

# %%
data = data.rename(columns=data.iloc[0])
data= data.drop(data.index[0])

data.head()
# Out:
#      시군구명   도로명 소재지도로명주소                  소재지지번주소  횡단보도관리번호 횡단보도종류 자전거횡단도겸용여부  \
# 경상남도  양산시  양산대로      NaN  경상남도 양산시 하북면 용연리 1089-8  양산신-1001      1          N
# 경상남도  양산시  양산대로      NaN  경상남도 양산시 하북면 용연리 1012-4  양산신-1002      1          N
# 경상남도  양산시  양산대로      NaN  경상남도 양산시 하북면 용연리 1145-3  양산신-1005      1          N
# 경상남도  양산시  양산대로      NaN  경상남도 양산시 하북면 백록리 1040-1  양산신-1007      1          N
# 경상남도  양산시  양산대로      NaN  경상남도 양산시 하북면 백록리 1009-3  양산신-1008      1          N
#
#      고원식적용여부         위도          경도  ... 적색신호시간 교통섬유무 보도턱낮춤여부 점자블록유무 집중조명시설유무  \
# 경상남도       N  35.431776  129.067611  ...    NaN     Y       Y      N        Y
# 경상남도       N  35.433768  129.068334  ...    NaN     N       Y      N        Y
# 경상남도       N  35.442733  129.072161  ...    NaN     N       Y      N        Y
# 경상남도       N  35.455274  129.076969  ...    NaN     N       Y      N        Y
# 경상남도       N  35.460196  129.079229  ...    NaN     N       Y      N        Y
#
# ...

# %%
data_ = data.query('index=="경상남도"')
data_
# Out:
#      시군구명   도로명 소재지도로명주소                  소재지지번주소  횡단보도관리번호 횡단보도종류 자전거횡단도겸용여부  \
# 경상남도  양산시  양산대로      NaN  경상남도 양산시 하북면 용연리 1089-8  양산신-1001      1          N
# 경상남도  양산시  양산대로      NaN  경상남도 양산시 하북면 용연리 1012-4  양산신-1002      1          N
# 경상남도  양산시  양산대로      NaN  경상남도 양산시 하북면 용연리 1145-3  양산신-1005      1          N
# 경상남도  양산시  양산대로      NaN  경상남도 양산시 하북면 백록리 1040-1  양산신-1007      1          N
# 경상남도  양산시  양산대로      NaN  경상남도 양산시 하북면 백록리 1009-3  양산신-1008      1          N
# ...   ...   ...      ...                      ...       ...    ...        ...
# 경상남도  양산시    시도      NaN    경상남도 양산시 물금읍 범어리 2751  양산신-9013      1          N
# 경상남도  양산시    시도      NaN    경상남도 양산시 물금읍 범어리 2751  양산신-9013      1          N
# 경상남도  양산시    시도      NaN    경상남도 양산시 물금읍 범어리 2751  양산신-9014      1          N
# 경상남도  양산시    시도      NaN    경상남도 양산시 물금읍 범어리 2749  양산신-9015      1          Y
# 경상남도  양산시    시도      NaN    경상남도 양산시 물금읍 범어리 2749  양산신-9015      1          Y
#
# ...

# %%
data_ = data.query('index=="서울"')
data_
# Out:
# Empty DataFrame
# Columns: [시군구명, 도로명, 소재지도로명주소, 소재지지번주소, 횡단보도관리번호, 횡단보도종류, 자전거횡단도겸용여부, 고원식적용여부, 위도, 경도, 차로수, 횡단보도폭, 횡단보도연장, 보행자신호등유무, 보행자작동신호기유무, 음향신호기설치여부, 녹색신호시간, 적색신호시간, 교통섬유무, 보도턱낮춤여부, 점자블록유무, 집중조명시설유무, 관리기관명, 관리기관전화번호, 데이터기준일자, 제공기관코드, 제공기관명]
# Index: []
#
# [0 rows x 27 columns]
