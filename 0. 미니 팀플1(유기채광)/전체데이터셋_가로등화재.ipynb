# %%
import pandas as pd

data1 = pd.read_csv('all/d/강원도.csv')
data2 = pd.read_csv('all/d/서울.csv')
data3 = pd.read_csv('all/d/전북.csv')
data4 = pd.read_csv('all/경기도가평군.csv')
data5 = pd.read_csv('all/광주광역시광산구.csv')
data6 = pd.read_csv('all/전라남도신안군.csv')
data7 = pd.read_csv('all/충청남도아산시.csv')
data8 = pd.read_csv('all/충청북도진천군.csv')

# %%
q1=pd.concat([data2,data4,data1,data3,data6,data5,data8,data7],ignore_index=True)
q1
# Out:
#      Unnamed: 0    시도명 시군구명 읍/면/동  설치유무  화재발생횟수    화재발생비율  어린이보호구역수  어린이보호구역비율
# 0           0.0  서울특별시  강서구   염창동   0.0    18.0  0.049451       NaN        NaN
# 1           1.0  서울특별시  강서구  등촌1동   0.0     0.0  0.000000       NaN        NaN
# 2           2.0  서울특별시  강서구  등촌2동   0.0     0.0  0.000000       NaN        NaN
# 3           3.0  서울특별시  강서구  등촌3동   0.0     0.0  0.000000       NaN        NaN
# 4           4.0  서울특별시  강서구  화곡본동   0.0     0.0  0.000000       NaN        NaN
# ..          ...    ...  ...   ...   ...     ...       ...       ...        ...
# 356         NaN   충청남도  아산시   장존동   0.0     2.0  0.006920       NaN        NaN
# 357         NaN   충청남도  아산시   점양동   0.0     1.0  0.003460       NaN        NaN
# 358         NaN   충청남도  아산시   좌부동   0.0     1.0  0.003460       NaN        NaN
# 359         NaN   충청남도  아산시   초사동   0.0     3.0  0.010381       NaN        NaN
# 360         NaN   충청남도  아산시   풍기동   0.0     3.0  0.010381       NaN        NaN
#
# [361 rows x 9 columns]

# %%
q1.to_csv('all/전국dataset.csv')

# %%
d = pd.read_csv('all/d/강원도.csv')

# %%
d
# Out:
#     Unnamed: 0  시도명 시군구명  읍/면/동  설치유무  화재발생횟수    화재발생비율
# 0            0  강원도  강릉시   주문진읍   1.0    26.0  0.086957
# 1            1  강원도  강릉시    성산면   0.0    19.0  0.063545
# 2            2  강원도  강릉시    왕산면   0.0     8.0  0.026756
# 3            3  강원도  강릉시    구정면   0.0     8.0  0.026756
# 4            4  강원도  강릉시    강동면   1.0    25.0  0.083612
# ..         ...  ...  ...    ...   ...     ...       ...
# 92          92  강원도  춘천시  중앙로1가   0.0     1.0  0.003460
# 93          93  강원도  춘천시  중앙로3가   0.0     1.0  0.003460
# 94          94  강원도  춘천시    칠전동   0.0     3.0  0.010381
# 95          95  강원도  춘천시    효자동   1.0    15.0  0.051903
# 96          96  강원도  춘천시    후평동   1.0    24.0  0.083045
#
# [97 rows x 7 columns]
