# %%
# 창 띄우기 
import sys
from PyQt5.QtWidgets import QApplication, QWidget

class MyApp(QWidget):

  def __init__(self):   # self = MyApp 객체
    super().__init__()
    self.initUI()

  def initUI(self):
    self.setWindowTitle('My First Application')  # 타이틀바에 나타나는 창의 제목 설정
    self.move(300,300)  # 위젯을 스크린의 x 300 y 300px 의 위치로 이동
    self.resize(400,200)  # 위젯의 크기를 너비 400 높이 200px로 조절 
    self.show()


if __name__ == '__main__':  # 현재 모듈의 이름이 저장되는 내장 변수 
  app= QApplication(sys.argv) # 어플리케이션 객체 생성 
  ex= MyApp()
  sys.exit(app.exec_())

# %%
# 어플리케이션 아이콘 넣기
import sys
from PyQt5.QtWidgets import QApplication, QWidget
from PyQt5.QtGui import QIcon

class MyApp(QWidget):

  def __init__(self):   # self = MyApp 객체
    super().__init__()
    self.initUI()

  def initUI(self):
    self.setWindowTitle('Icon')  # 타이틀바에 나타나는 창의 제목 설정
    self.setWindowIcon(QIcon('heart.png')) # 아이콘 설정
    self.setGeometry(300,300,300,200)
    self.show()


if __name__ == '__main__':  # 현재 모듈의 이름이 저장되는 내장 변수 
  app= QApplication(sys.argv) # 어플리케이션 객체 생성 
  ex= MyApp()
  sys.exit(app.exec_())

# %%
# 창닫기
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton
from PyQt5.QtGui import QIcon
from PyQt5.QtCore import QCoreApplication
from PyQt5 import uic


# UI 연결
form_class = uic.loadUiType("dashboard_pyqt.ui")[0]

#화면을 띄우는데 사용되는 Class 선언
class WindowClass(QMainWindow, form_class) :
    def __init__(self) :
        super().__init__()
        self.setupUi(self)

    def initUI(self):
        btn= QPushButton('Quit',self) # 푸시버튼 만들기
        btn.move(50,50)
        btn.resize(btn.sizeHint())
        btn.clicked.connect(QCoreApplication.instance().quit) # click시그널 만들어짐 . /instance는 현재 인스턴스 반환
                                                            #  clicked 시그널은 어플리케이션을 종료하는 quit메서드에 연결

    
        self.setWindowTitle('Quit')  # 타이틀바에 나타나는 창의 제목 설정
        self.setWindowIcon(QIcon('heart.png')) # 아이콘 설정
        self.show()


if __name__ == '__main__':  # 현재 모듈의 이름이 저장되는 내장 변수 
  app= QApplication(sys.argv) # 어플리케이션 객체 생성 
  ex= MyApp()
  sys.exit(app.exec_())

# %%
# Qt Designer의 UI는 저장버튼(Control + S / Command + S)를 누르면 저장을 할 수 있습니다.
# 저장된 UI파일은 XML의 형식을 가지며, Python 코드에서 이 XML 파일을 Import한 후 위젯들에 기능을 할당해주면 
# 실제로 기능을 가지고 작동하는 GUI프로그램이 되는 것입니다. 직접 XML형식의 ui파일을 수정하여 
# 레이아웃을 수정할 수도 있습니다.

# %%
# qt designer 연결하고 quit 버튼 만들기 


import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton
from PyQt5.QtGui import QIcon
from PyQt5.QtCore import QCoreApplication
from PyQt5 import uic
from PyQt5.QtWidgets import *

form_class = uic.loadUiType("dashboard_pyqt.ui")[0]

class WindowClass(QMainWindow, form_class) :
    def __init__(self) :
        super().__init__()
        self.setupUi(self)

        self.setWindowIcon(QIcon('heart.png')) # 아이콘 설정
        
        self.btn_1.clicked.connect(self.button1Function)
        
        btn= QPushButton('Quit',self) # 푸시버튼 만들기
        btn.move(50,50)
        btn.resize(btn.sizeHint())
        btn.clicked.connect(QCoreApplication.instance().quit) # click시그널 만들어짐 . /instance는 현재 인스턴스 반환
                                                            #  clicked 시그널은 어플리케이션을 종료하는 quit메서드에 연결
        
        btn = QPushButton('Button', self)
        btn.setToolTip('This is a <b>QPushButton</b> widget')
        btn.move(50, 50)
        btn.resize(btn.sizeHint())
        btn.clicked.connect(QCoreApplication.instance().button1Function)
        
        #버튼에 기능을 연결하는 코드
        self.btn_1.clicked.connect(self.button1Function)
        self.btn_2.clicked.connect(self.button2Function)

        btn_1이 눌리면 작동할 함수
        def button1Function(self) :
            print("btn_1 Clicked")
        
        
    
        self.setWindowTitle('HIHIHI')  # 타이틀바에 나타나는 창의 제목 설정
        self.setWindowIcon(QIcon('heart.png')) # 아이콘 설정
        self.show()


        
if __name__ == "__main__" :
    app = QApplication(sys.argv)
    myWindow = WindowClass() 
    myWindow.show()
    app.exec_()

# %%
##########

# %%
import sys
import sys

from PyQt5 import QtCore, QtGui, QtWidgets, uic
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QGridLayout, QFileDialog, QLabel
from PyQt5.QtGui import *
from PyQt5.QtCore import QCoreApplication
from PyQt5 import uic
from PyQt5.QtWidgets import *

form_class = uic.loadUiType("dashboard_pyqt.ui")[0]

class WindowClass(QMainWindow, form_class) :
    def __init__(self) :
        super().__init__()
        self.setupUi(self)
        self.initUI()
    
        self.setWindowTitle('HIHIHI')  # 타이틀바에 나타나는 창의 제목 설정
        self.setWindowIcon(QIcon('heart.png')) # 아이콘 설정
        self.show()

    # 파일 경로 dialog 설정
    def initUI(self):
        self.setWindowTitle("파일 오픈") # 파일 이름 설정하기
        self.img_button.clicked.connect(self.fileopen) # pushButton = object name 
        
    def fileopen(self):
        global filename
        filename = QtWidgets.QFileDialog.getOpenFileName(self, 'Open File') 
    
    
    
        
if __name__ == "__main__" :
    app = QApplication(sys.argv)
    myWindow = WindowClass() 
    myWindow.show()
    app.exec_()

# %%
import sys
import sys

from PyQt5 import QtCore, QtGui, QtWidgets, uic
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QGridLayout, QFileDialog, QLabel
from PyQt5.QtGui import *
from PyQt5.QtCore import QCoreApplication
from PyQt5 import uic
from PyQt5.QtWidgets import *

form_class = uic.loadUiType("dashboard_pyqt.ui")[0]

class WindowClass(QMainWindow, form_class) :
    def __init__(self) :
        super().__init__()
        self.setupUi(self)
#         self.initUI()
#         self.filedialog_open()
    
        self.setWindowTitle('HIHIHI')  # 타이틀바에 나타나는 창의 제목 설정
        self.setWindowIcon(QIcon('heart.png')) # 아이콘 설정
        self.show()

        
        # QButton 위젯 생성 - FileDialog 을 띄위기 위한 버튼
        self.setWindowTitle("파일 오픈") # 파일 이름 설정하기
        self.img_button.clicked.connect(self.filedialog_open)
        
        # 이미지를 추가할 라벨
        self.image_frame = QLabel(self)

    def filedialog_open(self):
        fname = QFileDialog.getOpenFileName(self, 'Open File', '',
                                            'All File(*);; Image File(*.png *.jpg)')

        if fname[0]:
            # QPixmap 객체
            self.pixmap = QPixmap(fname[0])        
            self.image_frame.setpixmap(self.pixmap)
        
#         if fname[0]:
#             # QPixmap 객체
#             pixmap = QPixmap(fname[0])

#             self.image_frame.setPixmap(pixmap)  # 이미지 세팅
#             self.image_frame.setContentsMargins(10, 50, 10, 10)
#             self.image_frame.resize(pixmap.width(), pixmap.height())

#             # 이미지의 크기에 맞게 Resize
#             self.resize(pixmap.width(), pixmap.height())

#         else:
#             QMessageBox.about(self, 'Warning', '파일을 선택하지 않았습니다.')
    
        
if __name__ == "__main__" :
    app = QApplication(sys.argv)
    myWindow = WindowClass() 
    myWindow.show()
    app.exec_()

# %%
import sys
from PyQt5 import QtCore, QtGui, QtWidgets, uic
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QGridLayout, QFileDialog, QLabel
from PyQt5.QtGui import *
from PyQt5.QtCore import QCoreApplication
from PyQt5 import uic
from PyQt5.QtWidgets import *
import cv2

form_class = uic.loadUiType("dashboard_pyqt.ui")[0]

class WindowClass(QMainWindow, form_class) :
    def __init__(self) :
        super().__init__()
        self.setupUi(self)
#         self.initUI()
#         self.filedialog_open()
    
        self.setWindowTitle('HIHIHI')  # 타이틀바에 나타나는 창의 제목 설정
        self.setWindowIcon(QIcon('heart.png')) # 아이콘 설정
        self.show()

        self.img_button.clicked.connect(self.filedialog_open)
        
        # 이미지를 추가할 라벨
        self.image_frame = QLabel(self)
            
    def filedialog_open(self):
        fname = QFileDialog.getOpenFileName(self, 'Open File')[0]
        self.loadimage(fname)
        self.image_frame= QGraphicsScene()
        tempmap= QtGui.QPixmap(fname)
        self.image_frame.addpixmap(tempmap)
        print(self.fname)
        
    def loadimage(self,fname):
        self.image= cv2.imread(fname)
        

        
if __name__ == "__main__" :
    app = QApplication(sys.argv)
    myWindow = WindowClass() 
    myWindow.show()
    app.exec_()
    
    
#######################################

# %%
import sys
import sys

from PyQt5 import QtCore, QtGui, QtWidgets, uic
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QGridLayout, QFileDialog, QLabel
from PyQt5.QtGui import *
from PyQt5.QtCore import QCoreApplication
from PyQt5 import uic
from PyQt5.QtWidgets import *

form_class = uic.loadUiType("dashboard_pyqt.ui")[0]

class WindowClass(QWidget, form_class) :
    def __init__(self) :
        super().__init__()
#         self.setupUi(self)
        self.initUI()

        
    def initUI(self):
#         self.setGeometry()
        self.sid = QImage("input.png").scaled(481,621)

        # QButton 위젯 생성 - FileDialog 을 띄위기 위한 버튼
        self.img_button.clicked.connect(self.filedialog_open)
        
        self.setWindowTitle('HIHIHI')  # 타이틀바에 나타나는 창의 제목 설정
        self.setWindowIcon(QIcon('heart.png')) # 아이콘 설정
        self.show()


    
    
    # 이미지를 추가할 라벨
#         self.image_frame = QLabel(self)
    def drawImage(self,painter):
        painter.drawImage(5,15,self.sid)

    def filedialog_open(self):
        fname,_ = QFileDialog.getOpenFileName(self,"불러올 이미지 선택","",
                                             "All File(*);; Image File(*.png *.jpg)")
        if fname:
            print(fname)
            self.sid= QImage(fname).scaled(481,621)


if __name__ == "__main__" :
    app = QApplication([sys.argv])
    myWindow = WindowClass() 
    myWindow.show()
    app.exec_()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-e4a62fdfe403> in <module>
#       9 from PyQt5.QtWidgets import *
#      10
# ---> 11 form_class = uic.loadUiType("dashboard_pyqt.ui")[0]
#      12
#      13 class WindowClass(QWidget, form_class) :
#
# C:\Tools\Anaconda3\lib\site-packages\PyQt5\uic\__init__.py in loadUiType(uifile, from_imports, resource_suffix, import_from)
#     202
#     203     ui_globals = {}
# --> 204     exec(code_string.getvalue(), ui_globals)
#     205
#     206     uiclass = winfo["uiclass"]
#
# <string> in <module>
#
# ModuleNotFoundError: No module named 'mainwindow'

# %%
import sys
from PyQt5 import QtCore, QtGui, QtWidgets, uic
from PyQt5.QtWidgets import QMainWindow, QLabel, QPushButton, \
    QApplication, QFileDialog, QMessageBox
from PyQt5.QtGui import *

form_class = uic.loadUiType("dashboard_pyqt.ui")[0]


class MainWindow(QMainWindow, form_class):
    def __init__(self):
        super().__init__()
        self.setupUi(self) # ui 설정
        self.setWindowTitle('HIHIHIHI') #타이틀 

        self.img_button.clicked.connect(self.filedialog_open) # 버튼누르면 파일경로 dialog 생성
        self.setWindowIcon(QIcon('heart.png')) # 아이콘 설정

#         # 이미지를 추가할 라벨
        self.image_frame = QLabel(self)

    def filedialog_open(self):
        fname = QFileDialog.getOpenFileName(self, 'Open File', '',
                                            'All File(*);; Image File(*.png *.jpg)')

        if fname[0]:
            # QPixmap 객체
            pixmap = QPixmap(fname[0])            
            pixmap = pixmap.scaled(481,621) # 이미지 스케일 변화
            self.image_frame.setPixmap(pixmap)  # 이미지 세팅
           
            self.image_frame.resize(481,621)  # 프레임 스케일
            
#             이미지의 크기에 맞게 Resize
#             self.resize(481,621)    # 전체화면 스케일

        else:
            QMessageBox.about(self, 'Warning', '파일을 선택하지 않았습니다.')


if __name__ == '__main__':
    app = QApplication(sys.argv)
    mainWindow = MainWindow()
    mainWindow.show()
    sys.exit(app.exec_())
    
    ####이게 그나마 잘됨..

# %%
import sys
from PyQt5 import QtCore, QtGui, QtWidgets, uic
from PyQt5.QtWidgets import QMainWindow, QLabel, QPushButton, \
    QApplication, QFileDialog, QMessageBox
from PyQt5.QtGui import *

form_class = uic.loadUiType("dashboard_pyqt.ui")[0]

class MainWindow(QMainWindow, form_class):
    def __init__(self):
        super().__init__()
        self.setupUi(self) # ui 설정
        self.setWindowTitle('HIHIHIHI') #타이틀 

        self.img_button.clicked.connect(self.filedialog_open) # 버튼누르면 파일경로 dialog 생성
        self.setWindowIcon(QIcon('heart.png')) # 아이콘 설정

#         # 이미지를 추가할 라벨
        self.image_frame = QLabel(self)

    def filedialog_open(self):
        fname = QFileDialog.getOpenFileName(self, 'Open File', '',
                                            'All File(*);; Image File(*.png *.jpg)')

        if fname[0]:
            # QPixmap 객체
            self.pixmap = QPixmap(fname[0])            
            self.pixmap = self.pixmap.scaled(481,621) # 이미지 스케일 변화
            self.image_frame.move(30,30) # 시작위치
            self.image_frame.setPixmap(self.pixmap)  # 이미지 세팅
            self.image_frame.setContentsMargins(0,0,0,0)
            self.image_frame.resize(481,621)  # 프레임 스케일
            
#             이미지의 크기에 맞게 Resize
#             self.resize(481,621)    # 전체화면 스케일
            
        else:
            QMessageBox.about(self, 'Warning', '파일을 선택하지 않았습니다.')
            
        return fname[0]

if __name__ == '__main__':
    app = QApplication(sys.argv)
    mainWindow = MainWindow()
    mainWindow.show()
    sys.exit(app.exec_())
