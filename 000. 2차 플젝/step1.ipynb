# %%
import sys
from PyQt5.QtCore import QDate, QDateTime, QTimer, QTime
from PyQt5 import QtCore, QtGui, QtWidgets, uic
from PyQt5.QtWidgets import QMainWindow, QLabel, QPushButton, QApplication, QFileDialog, QMessageBox,QDialog
from PyQt5.QtGui import *
from PyQt5.uic import loadUi
from time import sleep

form_secondwindow =uic.loadUiType("dashboard1.ui")[0]

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(1000, 800)
        icon = QtGui.QIcon()
        icon.addPixmap(QtGui.QPixmap("./boneage.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        MainWindow.setWindowIcon(icon)
        MainWindow.setStyleSheet("background-color: rgb(82, 89, 103);")
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.frame = QtWidgets.QFrame(self.centralwidget)
        self.frame.setGeometry(QtCore.QRect(25, 20, 950, 700))
        self.frame.setStyleSheet("color: rgb(255, 255, 255);")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Sunken)
        self.frame.setLineWidth(10)
        self.frame.setObjectName("frame")
        self.img_3 = QtWidgets.QLabel(self.frame)
        self.img_3.setGeometry(QtCore.QRect(20, 20, 911, 661))
        font = QtGui.QFont()
        font.setFamily("AcadEref")
        font.setPointSize(12)
        self.img_3.setFont(font)
        self.img_3.setStyleSheet("image: url(./boneage.png);")
        self.img_3.setText("")
        self.img_3.setObjectName("img_3")
        self.startButton_3 = QtWidgets.QPushButton(self.frame)
        self.startButton_3.setEnabled(True)
        self.startButton_3.setGeometry(QtCore.QRect(570, 590, 291, 61))
        
        font = QtGui.QFont()
        font.setFamily("Bauhaus 93")
        font.setPointSize(28)
        font.setBold(False)
        font.setWeight(50)
        self.startButton_3.setFont(font)
        self.startButton_3.setMouseTracking(True)
        self.startButton_3.setFocusPolicy(QtCore.Qt.ClickFocus)
        self.startButton_3.setContextMenuPolicy(QtCore.Qt.NoContextMenu)
        self.startButton_3.setStyleSheet("background-color: rgb(188, 188, 188);")
        self.startButton_3.setAutoDefault(False)
        self.startButton_3.setDefault(True)
        self.startButton_3.setFlat(False)
        self.startButton_3.setObjectName("startButton_3")
        self.click_3 = QtWidgets.QLabel(self.frame)
        self.click_3.setGeometry(QtCore.QRect(570, 540, 291, 41))
        font = QtGui.QFont()
        font.setFamily("Arial Rounded MT Bold")
        font.setPointSize(11)
        font.setBold(False)
        font.setItalic(False)
        font.setWeight(50)
        self.click_3.setFont(font)
        self.click_3.setStyleSheet("font: 11pt \"Arial Rounded MT Bold\";\n"
"color: rgb(255, 0, 0);")
        self.click_3.setLineWidth(0)
        self.click_3.setTextFormat(QtCore.Qt.AutoText)
        self.click_3.setAlignment(QtCore.Qt.AlignBottom|QtCore.Qt.AlignHCenter)
        self.click_3.setWordWrap(True)
        self.click_3.setIndent(-3)
        self.click_3.setTextInteractionFlags(QtCore.Qt.NoTextInteraction)
        self.click_3.setObjectName("click_3")
        self.time_3 = QtWidgets.QDateTimeEdit(self.frame)
        self.time_3.setGeometry(QtCore.QRect(10, 10, 194, 22))
        font = QtGui.QFont()
        font.setFamily("Adobe 고딕 Std B")
        font.setPointSize(10)
        font.setBold(True)
        font.setWeight(75)
        self.time_3.setFont(font)
        self.time_3.setWrapping(False)
        self.time_3.setFrame(False)
        self.time_3.setAlignment(QtCore.Qt.AlignCenter)
        self.time_3.setReadOnly(True)
        self.time_3.setButtonSymbols(QtWidgets.QAbstractSpinBox.NoButtons)
        self.time_3.setDateTime(QDateTime.currentDateTime())
        self.time_3.setObjectName("time_3")
        self.progressBar_3 = QtWidgets.QProgressBar(self.frame)
        self.progressBar_3.setGeometry(QtCore.QRect(570, 660, 331, 23))
        self.progressBar_3.setFocusPolicy(QtCore.Qt.TabFocus)
        self.progressBar_3.setContextMenuPolicy(QtCore.Qt.PreventContextMenu)
        self.progressBar_3.setAutoFillBackground(False)
        self.progressBar_3.setProperty("value", 60)
        self.progressBar_3.setInvertedAppearance(False)
        self.progressBar_3.setTextDirection(QtWidgets.QProgressBar.TopToBottom)
        self.progressBar_3.setObjectName("progressBar_3")
        self.label = QtWidgets.QLabel(self.centralwidget)
        self.label.setGeometry(QtCore.QRect(100, 170, 821, 151))
        font = QtGui.QFont()
        font.setFamily("Algerian")
        font.setPointSize(52)
        font.setBold(True)
        font.setWeight(75)
        self.label.setFont(font)
        self.label.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:0, y2:0, stop:0 rgba(0, 0, 0, 0), stop:1 rgba(255, 255, 255, 0));")
        self.label.setIndent(-1)
        self.label.setTextInteractionFlags(QtCore.Qt.NoTextInteraction)
        self.label.setObjectName("label")
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 1000, 26))
        self.menubar.setObjectName("menubar")
        MainWindow.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)

        self.retranslateUi(MainWindow)
        self.startButton_3.clicked.connect(self.start)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "Bone Age"))
        self.startButton_3.setText(_translate("MainWindow", "Start"))
        self.click_3.setText(_translate("MainWindow", "Click !!"))
        self.time_3.setDisplayFormat(_translate("MainWindow", "yyyy-MM-dd  hh:mm"))
        self.label.setText(_translate("MainWindow", "<html><head/><body><p><span style=\" color:#ffffff;\">Bone Age predict</span></p></body></html>"))

    def start(self):
        self.startButton_3.setEnabled(False)
        self.progressBar_3.reset
        self.progressBar_3.setMinimum(0)
        self.progressBar_3.setMaximum(0)
      
        
        
        # 모델 실행!!!!! 끝나면 클릭버튼 뜨기.
        _translate = QtCore.QCoreApplication.translate
        sleep(0.2)
        self.click_3.setText(_translate("step1", "Click again !!"))
        self.startButton_3.setEnabled(True)
        self.startButton_3.clicked.connect(self.next_page)
    
    def next_page(self):
        MainWindow.hide()
        se = secondwindow()
        se.exec()


class secondwindow(QDialog, QtWidgets.QWidget, form_secondwindow):
    def __init__(self):
        super(secondwindow, self).__init__()
        loadUi("dashboard1.ui", self)
        self.time.setDateTime(QDateTime.currentDateTime())
        # self.img_button.clicked.connect(self.filedialog_open)
        # self.next_button.clicked.connect(self.gotonextpage)
        self.image_frame = QLabel(self)
             # 이미지 불러오기
            
        self.next_button.clicked.connect(self.gotonextpage) ## 승혜 추가 (페이지 넘기기)
        
    def filedialog_open(self):
        fname = QFileDialog.getOpenFileName(self, 'Open File', '',
                                            'All File(*);; Image File(*.png *.jpg)')

        if fname[0]:
            # QPixmap 객체
            self.pixmap = QPixmap(fname[0])            
            self.pixmap = self.pixmap.scaled(481,621) # 이미지 스케일 변화
            self.image_frame.move(50,50) # 시작위치
            self.image_frame.setPixmap(self.pixmap)  # 이미지 세팅
            self.image_frame.setContentsMargins(0,0,0,0)
            self.image_frame.resize(481,621)  # 프레임 스케일
            
#             이미지의 크기에 맞게 Resize
#             self.resize(481,621)    # 전체화면 스케일
            
        else:
            QMessageBox.about(self, 'Warning', '파일을 선택하지 않았습니다.')
            
        return fname[0]

    # # 다음페이지로 
    def gotonextpage(self):
        widget.setCurrentIndex(widget.currentIndex()+1)
        self.show()



if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Tools\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
