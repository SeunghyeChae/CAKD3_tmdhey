# %%
# 과제
# <K-digital training 3기>만들기 

text= '<k-digital traning 3기>'
text_=text.lstrip('<')
print('<'+text_.title())
# Out:
# <K-Digital Traning 3기>

# %%
# Q. 원하는 웹 사이트를 requests 모듈과 urllib 모듈로 가져와서 text로 출력하세요.
import requests

URL= 'https://www.op.gg/champion/diana/statistics/jungle'

data = requests.get(URL).text
print(data)
# Out:
# 	<!DOCTYPE html>
# 	<!--
# 	  ,ad8888ba,   88888888ba         ,ad8888ba,    ,ad8888ba,
# 	 d8"'    `"8b  88      "8b       d8"'    `"8b  d8"'    `"8b
# 	d8'        `8b 88      ,8P      d8'           d8'
# 	88          88 88aaaaaa8P'      88            88
# 	88          88 88""""""'        88      88888 88      88888
# 	Y8,        ,8P 88               Y8,        88 Y8,        88
# 	 Y8a.    .a8P  88                Y8a.    .a88  Y8a.    .a88
# 	  `"Y8888Y"'   88     dev@op.gg   `"Y88888P"    `"Y88888P"
#
# 		 Copyright © 2013-2021 OP.GG. All rights reserved.
# -->
# <html lang="en_US">
# <head>
# 	<script>
# 		(function(t, l) {
# 			try {
# 				let w = window,
# 						d = document,
# 						s = d.createElement("script"),
# 						f = d.getElementsByTagName("script")[0];
# 				w[t] =
# 						w[t] ||
# 						function() {
# 							(w["_rgea"] = w["_rgea"] || [["uts", new Date()]]).push(
# 									Array.prototype.slice.call(arguments)
# 							);
# 							w.RGEA && w.RGEA.p();
# 						};
# ...

# %%
import urllib

URL = URL= 'https://www.op.gg/champion/diana/statistics/jungle'
response = urllib.request.urlopen(URL)
_data = response.read().decode('utf-8')
print(_data)
# Out:
# 	<!DOCTYPE html>
# 	<!--
# 	  ,ad8888ba,   88888888ba         ,ad8888ba,    ,ad8888ba,
# 	 d8"'    `"8b  88      "8b       d8"'    `"8b  d8"'    `"8b
# 	d8'        `8b 88      ,8P      d8'           d8'
# 	88          88 88aaaaaa8P'      88            88
# 	88          88 88""""""'        88      88888 88      88888
# 	Y8,        ,8P 88               Y8,        88 Y8,        88
# 	 Y8a.    .a8P  88                Y8a.    .a88  Y8a.    .a88
# 	  `"Y8888Y"'   88     dev@op.gg   `"Y88888P"    `"Y88888P"
#
# 		 Copyright © 2013-2021 OP.GG. All rights reserved.
# -->
# <html lang="en_US">
# <head>
# 	<script>
# 		(function(t, l) {
# 			try {
# 				let w = window,
# 						d = document,
# 						s = d.createElement("script"),
# 						f = d.getElementsByTagName("script")[0];
# 				w[t] =
# 						w[t] ||
# 						function() {
# 							(w["_rgea"] = w["_rgea"] || [["uts", new Date()]]).push(
# 									Array.prototype.slice.call(arguments)
# 							);
# 							w.RGEA && w.RGEA.p();
# 						};
# ...

# %%
# Q. 특정 단어를 출력하세요. 다이애나 출력 
import requests
response=requests.get(URL)
Html_text= response.text
word = Html_text.split('<h1 class="champion-stats-header-info__name">')[1]
word= word.split('</h1>')[0]
print(word)

# 왜 영어로 나오지...?
# Out:
# Diana

# %%
# Q. 웹에서 이미지를 다운 받아 저장하세요.(가능한 이미지 선택)

import urllib.request
img_src='https://blog.kakaocdn.net/dn/EewBm/btq5HCz17YM/9VzR2WeDPBy1jTdKcX1V6k/img.jpg'
img_name='diana.png'
urllib.request.urlretrieve(img_src,img_name)
# Out:
# ('diana.png', <http.client.HTTPMessage at 0x19a61b318e0>)
