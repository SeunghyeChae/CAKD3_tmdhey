# %%
import pandas as pd

data= pd.read_csv('dataset/politic.csv')

data

# print(df_auto.isnull().sum().sum())

# df_auto.shape
# Out:
#         국가 국가코드(ISO 2자리 코드)           정체명  \
# 0       가나               GH  공화제(대통령 중심제)
# 1       가봉               GA  공화제(대통령 중심제)
# 2     가이아나               GY     공화국(영연방국)
# 3      감비아               GM  공화제(대통령 중심제)
# 4       건지               GG           NaN
# ..     ...              ...           ...
# 218    핀란드               FI           공화국
# 219    필리핀               PH           공화제
# 220  핏케언 섬               PN           NaN
# 221    헝가리               HU           공화제
# 222     호주               AU         입헌군주제
#
#                                                   정부형태  \
# 0                                         공화국(대통령 중심제)
# 1                                       대통령 중심제(7년 임기)
# 2                                              대통령 중심제
# 3                                            대통령중심 공화국
# 4    총독(영국 여왕 임명), 집달관(Bailiff, 영국 여왕 임명), 단원제 의회, ...
# ..                                                 ...
# 218                               의원집정부제(대통령중심제+의원내각제)
# ...
