# %%
text="<k=digital traning 3기>"
text1= 'abc'
print(text[0])
print(text[-1])
print(text.capitalize()) #k만 대문자 - 안됨


print(text1.title())  #첫글자 대문자로
print(text1.upper())  #다 대문자로
# Out:
# <
# >
# <k=digital traning 3기>
# Abc
# ABC

# %%
# 과재 - 꺽쇠 포함 K만 대문자만들기 
text1="    <k=digital traning 3기>    "
text2= ';'

print(text1.strip() +text2) #공백없애기
print(text1.lstrip() + text2)
print(text1.rstrip() + text2)
# Out:
# <k=digital traning 3기>;
# <k=digital traning 3기>    ;
#     <k=digital traning 3기>;

# %%
# <div>k-digital training 3기</title>

text="<title>k-digital training 3기 </title>"

print(text.replace('<title>','<div>'))
print(text.replace('title', 'div'))
# Out:
# <div>k-digital training 3기 </title>
# <div>k-digital training 3기 </div>

# %%
import re
text=('111<head>안녕하세요</head>22')
body= re.search('111<head>.+</head>22',text) # . 의미는 all
print(body.group())

# %%
import requests
URL = 'https://naver.com'
response= requests.get(URL)
print(response.text)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 
# ...

# %%
text='''<meta name="twitter:description"
content=네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나보세요'''

# %%
import re
text='''<meta name="twitter:description"
content=네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나보세요'''
body = re.search('([가-힣]+\s?)+',text)
body = re.search('([가-힣]+ *)+',text)
print(body.group())
# Out:
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나보세요

# %%
# k -digital traning 3기 만 출력
import re
text= '<title>k-digital training 3기</title>'
re.sub("<title>","",text)
re.sub("</title>","",text)
#---------------------------------------or
text=re.sub('<.+?>','',text)
print(text)
# Out:
# k-digital training 3기

# %%
# Q. 'k-digital training 3기' 출력
text='''<head>안녕하세요...<title<k-digital training  3기</title>
반갑습니다...</head>'''

body=re.search('[a-z]'-.+[가-힣],text)
print(body.group())
# Out:
#   File "<ipython-input-39-8582fb213479>", line 5
#     body=re.search('[a-z]'-.+[가-힣],text)
#                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# requests 모듈: pip install requests 명령어로 설치, anaconda로 설치하면 기본 설치
# - import requests 로 모듈 사용후 사용

# %%
conda list
# Out:
# # packages in environment at C:\Users\SH\anaconda3\envs\cakd3:
# #
# # Name                    Version                   Build  Channel
# _tflow_select             2.3.0                     eigen
# absl-py                   0.12.0           py38haa95532_0
#
# Note: you may need to restart the kernel to use updated packages.
# aiohttp                   3.7.4            py38h2bbff1b_1
# argon2-cffi               20.1.0           py38h2bbff1b_1
# astor                     0.8.1            py38haa95532_0
# astunparse                1.6.3                      py_0
# async-timeout             3.0.1            py38haa95532_0
# async_generator           1.10               pyhd3eb1b0_0
# attrs                     21.2.0             pyhd3eb1b0_0
# autobahn                  21.2.1             pyhd8ed1ab_0    vpython
# backcall                  0.2.0              pyhd3eb1b0_0
# blas                      1.0                         mkl
# bleach                    3.3.0              pyhd3eb1b0_0
# ...

# %%
import requests
URL='http://www.naver.com'
response = requests.get(URL)
print(response.status_code)  #정상인지 확인

print(response.text)
# Out:
# 200
#
# ...

# %%
html_data=response.text
print(html_data.find('네이버'))
print(html_data[365:368])
# Out:
# 365
# 네이버

# %%
html_data=response.text
print(html_data.find('네이버 메인에서'))
print(html_data.find('보세요'))
print(html_data[365:397])
# Out:
# 365
# 394
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %%
# Q. 위 문제를 정규표현식으로 출력하세요.
import re
html_data=response.text
a = re.search('([가-힣]+\s?)+',html_data)
print(a.group())
# Out:
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %%
content = html_data.split('<meta property=')[1] #분리
content= re.search('네이버',content) #서치로 찾기
print(content.group())
# Out:
# 네이버

# %%
#get 메소드에 params인자를 넣어 함께 get 요청(파라미터:query)

import requests
URL='https://search.naver.com/search.naver'
params= {'query':'aa'}
response= requests.get(URL,params=params)
print(response.status_code)
print(response.text)
# Out:
# 200
# ...

# %%
import requests
URL='https://www.naver.com'
response= requests.get(URL)
content= response.text
body=re.search('<h3.*/h3>',content)
body=body.group()
body
# Out:
# '<h3 class="title"><a href="https://www.naver.com/NOTICE">공지사항</a> </h3>'

# %%
# ?: 있거나 없거나
body=re.sub('<.+?>','',body) ######유용하게알아두기 

print(body)
# Out:
# 3 class="title"> href="https://www.naver.com/NOTICE">공지사항a> h3>

# %%
#https://datalab.naver.com 에서 원피스를 출력 

import requests
URL='https://datalab.naver.com'
response= requests.get(URL)
html_text=response.text
temp=html_text.split('<span class="title">')[1]
print(temp.split('</span>')[0])
# Out:
# 원피스

# %%
# Q. 'https://search.shopping.naver.com/best100v2/main.nhn'에서 
#크록스를 출력하세요

# %%
# Q. URL=' http://snaver,com'에서 split()함수와 정규표현식을 이용하여
#['메일','커플','블로그','지식in','쇼핑']을 출력하세요


URL= 'http://naver.com '
response= request....

#정규표현식으로도 해보기 ..
이해가안가 
ㅠ
ㅠ
ㅅㅂ

# %% [markdown]
# urllib모듈이란: 파이썬의 표준 모듈로써 URL을 다루기 위한 모듈 패키지
#
# - 설치가 필요하지 않고 import urllib로 활용
# - requests 모듈과 마찬가지로 URL과 관련된 여러가지 기능들을 제공하는 하위모듈을 가지고있음
# - request  : URL을 열고 읽는 모듈 (HTTP 요청)
# - error: request모듈에서 발생하는 에러들을 포함하는 모듈
# - parseL URL을 파싱하는 모듈( URL해석 및 조작)
# - robots.txt 파일을 파싱하는 모듈

# %%
import urllib
URL= 'https://www.naver.com'
request= urllib.request.Request(URL)
print(request)
print(request.full_url)
print(request.type)
print(request.host)
# Out:
# ...
# https://www.naver.com
# https
# www.naver.com

# %%
# 과제 
import urllib
URL='https://www.naver.com'
response=urllib.request.urlopen(URL)
byte_data= response.read(500)
response.read().decode('utf-8') # 인코딩된거라 디코드
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
import urllib
URL='https://www.naver.com'
response=urllib.request.urlopen(URL)
byte_data= response.read(500)
text_data=byte_data.decode('utf-8')
print(text_data)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <m

# %%
#urllibrequest.urlretrieve():웹상의 이미지 저장
import urllib.request
img_src='https://homepages.cae.wisc.edu/~ece533/images/tulips.png'
new_name='img.png'
urllib.request.urlretrieve(img_src,new_name)
# Out:
# ('img.png', <http.client.HTTPMessage at 0x2c50ebd4490>)

# %%
#단순한 패턴을 읽을 때는 복잡한 정규표현식보다는 간단한 parse모듈을 사용
#urllib.parse: url을 6개로 분리하여 반환 

import urllib
parse=urllib.parse.urlparse('https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai'
)
print(parse)
print(parse[0])
print(parse[5])
print(parse[:5])
print(parse.query)
# Out:
# ParseResult(scheme='https', netloc='section.blog.naver.com', path='/Search/Post.naver', params='', query='pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai', fragment='')
# https
#
# ('https', 'section.blog.naver.com', '/Search/Post.naver', '', 'pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai')
# pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai

# %%
# 튜플(변경불가능)로 반환됨-> 리스트(변경가능)로 변경하여 활용
import urllib
parse= urllib.parse.urlparse('https://blog.naver.com/koreatech91;a=1>b=2#b')
print(parse)
parse=list(parse)
parse[1]='blog.dqum.net'
print(parse)
# Out:
# ParseResult(scheme='https', netloc='blog.naver.com', path='/koreatech91', params='a=1>b=2', query='', fragment='b')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-21ac965ee594> in <module>
#       2 parse= urllib.parse.urlparse('https://blog.naver.com/koreatech91;a=1>b=2#b')
#       3 print(parse)
# ----> 4 parse[1]='blog.dqum.net'
#       5 print(parse)
#
# TypeError: 'ParseResult' object does not support item assignment

# %%
# strip() 공백없애주는거 
# split() 잘라주는거 .앞뒤나눠서 인덱스가능
# A.replace(a,b)

# match 
# search
# find
# findall
# finditer
# sub (substitute)

#정규표현식~~

# 1차플젝 : 정형데이터로 데이터분석 
#제일 널리 쓰임 ~~ ..~ 
#기업
# 3차 플젝: 과제를 수행하기 위한 데이터 만들기..
#
