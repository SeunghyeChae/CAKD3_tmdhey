# %% [markdown]
# - 마우스 클릭: click()
# - 키보드 입력: send_keys()
# - 자바스크립트 삽입: execute_script()
# - 입력 양식 전송: submit()
# - 스크린샷: screenchot(파일이름)
# - 글자 지움: clear()
# - 뒤로 가기: back()
# - 앞으로 가기: forward()
#
# - find_element_by_id:id 속성을 사용하여 접근
# - find_element(s)_by_class_name: 클래스를 사용하여 접근
# - find_element(s)_by_name: 속성을 사용하여 접근
# - find_element(s)_by_xpath: 속성을 사용하여 접근
# - find_element(s)_by_link_text:앵커태그(a 태그)에 사용되는 텍스트로 접근
# - find_element(s)_by_partial_link_text:앵커태그(a 태그)에 사용되는 일부 텍스트로 접근
# - find_element(s)_by_tag_name: 태그를 사용하여 접근
# - find_element(s)_by_css_selector: CSS선택자를 사용하여 접근

# %%
# Q. 과제:  구글 검색에서 '이대역 맛집'을 찾아 상위 10개 출력 및 저장 

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

url= 'https://google.com'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

search_box2= driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_box2.send_keys('이대역 맛집')
search_box2.send_keys(Keys.RETURN)

#더보기 클릭
driver.find_element_by_class_name('MXl0lf.mtqGb').click()

restaurants=driver.find_elements_by_css_selector('div.uMdZh.tIxNaf.mnr-c > div > a > div > div.dbg0pd > div')

for i,t in enumerate(restaurants):
    if i<10:
        print(t.text)
        print(t.text, file= open('dataset/test_food.txt','a',encoding='utf-8'))
    else: 
        pass

driver.close()
# Out:
# 미스터서왕만두 이대점
# 란주탕슉
# 파파노다이닝
# 까이식당
# 고냉지
# 반서울
# 이대총각떡복이
# 이대종합분식
# 화상손만두
# 삭

# %%
# //*[@id="tsuid25"]/div/div/a/div/div[3]/span
# //*[@id="tsuid28"]/div[2]/div/a/div/div[3]/span
# //*[@id="tsuid31"]/div[2]/div/a/div/div[3]/span

# #tsuid23 > div > div > a > div > div.dbg0pd > span
# #tsuid26 > div.uMdZh.tIxNaf > div > a > div > div.dbg0pd > span

# %%
#뉴스 타이틀 링크 1개 가져오기
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://news.naver.com'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

# tlink= driver.find_element_by_partial_link_text('href')
# print(tlink.text)

elem=driver.find_element_by_tag_name('a')
print(elem.get_attribute('href'))
# Out:
# https://news.naver.com/#lnb

# %%
#뉴스 타이틀 링크 모두 가져오기 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://news.naver.com'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

# tlink= driver.find_element_by_partial_link_text('href')
# print(tlink.text)

elems= driver.find_elements_by_tag_name('a')
for e in elems:
    print(e.get_attribute('href'))
# Out:
# https://news.naver.com/#lnb
# https://news.naver.com/#main_content
# https://nid.naver.com/nidlogin.login
# javascript:;
# https://news.naver.com/#
# https://nid.naver.com/user2/api/naverProfile.nhn?m=checkIdType
# https://nid.naver.com/user2/api/naverProfile.nhn?m=checkIdType
# https://nid.naver.com/nidlogin.logout?returl=https%3A%2F%2Fnews.naver.com%2F
# https://mail.naver.com/
# https://nid.naver.com/user2/help/myInfo.nhn?menu=home
# https://nid.naver.com/user2/help/myInfo.nhn?m=viewSecurity&menu=security
# https://nid.naver.com/user2/eSign/v1/home/land
# https://nid.naver.com/membership/my
# https://pay.naver.com/
# https://blog.naver.com/MyBlog.naver
# https://section.cafe.naver.com/
# https://pay.naver.com/
# https://news.naver.com/#
# javascript:;
# https://noti.naver.com/index.nhn
# https://mail.naver.com/
# javascript:;
# https://news.naver.com/#
# https://news.naver.com/#
# https://news.naver.com/#
# https://news.naver.com/#
# https://news.naver.com/#
# ...

# %%
# 과제 
# 네이버 사이트에서 15개 selenium 함수를 이용하여 요소를 가져와서 출력하세요(15개.,! )


#id
# element_css_selector 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://naver.com'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

naver_box= driver.find_element_by_id('query')
naver_box.send_keys('무궁화')
s=driver.find_element_by_id('search_btn')
s.click()

info= driver.find_element_by_css_selector('#main_pack > section.sc_new.sp_nkindic._au_kindic_collection > div > div.nkindic_area > div:nth-child(1) > div.nkindic_content._svp_content > div.content_desc > div.api_txt_lines.desc')

print(info.text)
driver.close()
#아니 왜안대는거임 ? 
# 되넹
# Out:
# 쌍떡잎식물 아욱목 아욱과의 낙엽관목. 근화(槿花)라고도 한다. 무궁화는 한자어이지만 중국 문헌에는 나타나지 않고, 다만 《산해경》에 한국에 훈화초(薰華草:무궁화)가 있다는 기록이 있다. 내한성(耐寒性)으로 높이 2∼4m이고 때로는 거의 교목이 되는 것도 있다. 전체에 털이 없고 많은 가지를 치며 회색을 띤다. 잎은 늦게 돋아나고 어긋나며 자루가 짧고 마름모꼴 또는...

# %%
#element_class_name
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://naver.com'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

book= driver.find_element_by_class_name('btn_theme')
print(book.text)

driver.close()
# Out:
# 라이트 모드로 보기

# %%
#elements_class_name
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://naver.com'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

li= driver.find_elements_by_class_name('list_category')
for i,t in enumerate(li):
    if i<5:
        print(t.text)
    else:
        pass

driver.close()
# Out:
# 영화
# JOB&
# 테크
# 여행+
# 과학
# 리빙
# 건강
# 비즈니스
# 연애·결혼

# %%
# element_name
# element_xpath
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://naver.com'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

nav_box=driver.find_element_by_name('query')
nav_box.send_keys('크리스마스')
nav_box.send_keys(Keys.RETURN)

xmas=driver.find_element_by_xpath('//*[@id="main_pack"]/section[1]/div/div[2]/div/div[1]/p')
xmas_=xmas.text.strip('더보기')

print(xmas_)

driver.close()
# Out:
# 예수 그리스도의 탄생기념일로, 영어로 그리스도(Christ)의 미사(mass)를 의미하는 법정공휴일

# %%
# elements_name 
# elements는 없는데....

# %%
# elements _ xpath
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://naver.com'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

blog= driver.find_element_by_xpath('//*[@id="NM_FAVORITE"]/div[1]/ul[1]/li[3]/a')
blog.click()

time.sleep(1)
category=driver.find_elements_by_xpath(' //*[@id="content"]/section/div[1]/div/div/a/span')
for a in category:
    print(a.text)
     
driver.close()
# 왜 전체 하나만나올까....?  --> time.sleep 사용!!
# //*[@id="content"]/section/div[1]/div/div/a[1]/span
# //*[@id="content"]/section/div[1]/div/div/a[2]/span
# //*[@id="content"]/section/div[1]/div/div/a[3]/span
# Out:
# 전체
# 스포츠
# 좋은글·이미지
# 세계여행
# 미술·디자인
# 맛집
# 공연·전시
# 자동차

# %%
#elements_css_selector
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://naver.com'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

blog= driver.find_element_by_xpath('//*[@id="NM_FAVORITE"]/div[1]/ul[1]/li[3]/a')
blog.click()

time.sleep(1)
categories=driver.find_elements_by_css_selector('#content > section > div.heading_logout > div > div > a > span')
cat=[]
for category in categories:
    cat.append(category.text)

print(cat)

driver.close()
# Out:
# ['전체', '상품리뷰', '패션·미용', '세계여행', '맛집', '좋은글·이미지', '스타·연예인', '영화']

# %%
#element_link_text
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://naver.com'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

ee= driver.find_element_by_link_text('구독한 언론사')

print(ee)
print(ee.tag_name)
print(ee.text)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="dd72373c993cfe99abd98b62b32de965", element="edf86174-b4d4-46ec-94f4-578e99f273d0")>
# a
# 구독한 언론사

# %%
#elements_ link_text

 # elements는 모르겠는데...

# %%
#element_partial_linktext

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://finance.naver.com/'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

qq= driver.find_element_by_partial_link_text('코스닥')
print(qq.text)

driver.close()
# Out:
# [코스닥 마감]美 증시 훈풍에 상승…1030선 다시 회복

# %%
#elements_partial 

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://finance.naver.com/'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

qq= driver.find_elements_by_partial_link_text('코스피')
for i in qq:
    print(i.text)

driver.close()
# Out:
# [마켓뷰] 코스피, 델타 변이 공포에도 0.89% 상승 마감
# [시황종합] '4단계 첫날' 코스피 0.9%↑ 3240선…'기관+외인 사자'
# [마감시황]코스피, 美증시 훈풍에 상승…3250선 회복 눈앞
# 코스피
# 코스피200

# %%
#element_tag_name
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://finance.naver.com/'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

aa=driver.find_element_by_tag_name('iframe')
print(aa)
print(aa.text)
print(aa.tag_name)

driver.close()
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5b1763a450bc6624ac168876e44f3fe7", element="265a0143-cc40-4a28-8845-fadc8fc7aabd")>
#
# iframe

# %%
#elements_tag_name
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://finance.naver.com/'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

dd= driver.find_elements_by_tag_name('a')
for i, e in enumerate(dd):
    if i<5:
        print(e.get_attribute('href'))
    else:
        pass 
    
driver.close()
# Out:
# https://finance.naver.com/#menu
# https://finance.naver.com/#start
# https://nid.naver.com/nidlogin.login
# javascript:;
# https://finance.naver.com/#

# %%
#elements_tag_name
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://finance.naver.com/'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

dd= driver.find_elements_by_tag_name('script')
for i, e in enumerate(dd):
    if i<5:
        print(e)
        print(e.text)
    else:
        pass 
    
driver.close()
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3466c6df5cb394245ce5664c2fa4f22d", element="3007ce9b-d109-4c91-a082-f441d9d1d350")>
#
# <selenium.webdriver.remote.webelement.WebElement (session="3466c6df5cb394245ce5664c2fa4f22d", element="c613bc4b-465f-40fe-86e4-bf63fcf352cd")>
#
# <selenium.webdriver.remote.webelement.WebElement (session="3466c6df5cb394245ce5664c2fa4f22d", element="6a13778a-0b9b-4bc5-abc1-5e996b062aed")>
#
# <selenium.webdriver.remote.webelement.WebElement (session="3466c6df5cb394245ce5664c2fa4f22d", element="521d7419-6c06-4ac9-9033-5a7b5dc50e9b")>
#
# <selenium.webdriver.remote.webelement.WebElement (session="3466c6df5cb394245ce5664c2fa4f22d", element="e4c59faf-df1d-4dc9-9f3a-2fc6f0ccc613")>

# %%
# Q. urllib + bs4로 네이버 사이트에서 뉴스 5개를 가져와서 출력하세요

import urllib
import requests
from bs4 import BeautifulSoup

headers = { "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36" } 

URL='https://news.naver.com/'

response = urllib.request.Request(URL, headers=headers)
text = urllib.request.urlopen(response).read()
soup = BeautifulSoup(text,'html.parser')

headers = { "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36" } 


news=soup.select_all('ul>li>div.hdline_article_tit>a').string

for a,t in enumerate(news):
    if a<5:
        print(t)
        print(t.request.headers)
    else:
        pass

## 모르겠다..~
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-2e62f6d62863> in <module>
#      16
#      17
# ---> 18 news=soup.select_all('ul>li>div.hdline_article_tit>a').string
#      19
#      20 for a,t in enumerate(news):
#
# TypeError: 'NoneType' object is not callable

# %%
# 네이버 '항공권 검색'  들어가서 김포-제주 편도 날짜 고르고 항공권 검색 
# 시간걸리는부분 time 주기 
# 그러고 나오는 항공권 정보 가져오기

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://naver.com'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)


nav_box=driver.find_element_by_name('query')
nav_box.send_keys('항공권 검색')
nav_box.send_keys(Keys.RETURN)

time.sleep(1)
#김포선택
driver.find_element_by_xpath('//*[@id="_flight_section"]/div/div[2]/div[2]/div[1]/div[1]/div/h4/a/span[1]').click()
driver.find_element_by_xpath('//*[@id="_flight_section"]/div/div[2]/div[2]/div[1]/div[1]/div/div/table[1]/tbody/tr[1]/td[3]/a').click()

time.sleep(1)
#제주선택
driver.find_element_by_xpath('//*[@id="_flight_section"]/div/div[2]/div[2]/div[1]/div[2]/div/h4/a/span[1]').click()
driver.find_element_by_xpath('//*[@id="_flight_section"]/div/div[2]/div[2]/div[1]/div[2]/div/div/table[1]/tbody/tr[1]/td[1]/a').click()

time.sleep(1)
#편도 선택
driver.find_element_by_xpath('//*[@id="_flight_section"]/div/div[2]/div[1]/ul/li[1]/a').click()

time.sleep(1)
#가는날 선택 달력-19일
driver.find_element_by_xpath('//*[@id="_flight_section"]/div/div[2]/div[2]/div[2]/div/div[1]/div[1]/div/strong').click()
time.sleep(1)
driver.find_element_by_xpath('//*[@id="_flight_section"]/div/div[2]/div[2]/div[2]/div/div[1]/div[1]/div[2]/div/div[2]/div[1]/div/div[1]/table/tbody/tr[4]/td[2]/button').click()
time.sleep(10)

#검색 버튼
driver.find_element_by_xpath('//*[@id="_flight_section"]/div/div[2]/div[2]/div[2]/a').click()


inform=driver.find_elements_by_css_selector('#__next > div > div.container > div.List_content > div > div.domestic_results__yNAgI > div:nth-child(2) > div')
inform.text

driver.close()


##다른건 다 정상적으로 되는데 마지막 출력만 자꾸 오류남
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3baa308391cf> in <module>
#      38
#      39 inform=driver.find_elements_by_css_selector('#__next > div > div.container > div.List_content > div > div.domestic_results__yNAgI > div:nth-child(2) > div')
# ---> 40 inform.text
#      41
#      42 driver.close()
#
# AttributeError: 'list' object has no attribute 'text'

# %%
# driver.find_elements_by_css_selector('#__next > div > div.container > div.List_content > div > div.domestic_results__yNAgI > div:nth-child > button')
# airplane= driver.find_element_by_css_selector('#__next > div > div.container > div.List_content > div > div.selected_schedules > div > div > div.SelectedFlight_summary__1t3j9 > div.SelectedFlight_row__4oIWt > div > b')
# # from_time= driver.find_element_by_css_selector()
# # to_time= driver.find_element_by_css_selector()
# time_= driver.find_element_by_css_selector('#__next > div > div.container > div.List_content > div > div.selected_schedules > div > div > div.SelectedFlight_summary__1t3j9 > div.SelectedFlight_route__36vfe > div')
# price= driver.find_element_by_css_selector('#__next > div > div.container > div.List_content > div > div.selected_schedules > div > div > div.SelectedFlight_summary__1t3j9 > div.desc > b > i')

# print([airplane.text, time.text , price.text+'원~'])

#__next > div > div.container > div.List_content > div > div.domestic_results__yNAgI > div:nth-child(2) > button
#__next > div > div.container > div.List_content > div > div.domestic_results__yNAgI > div:nth-child(3) > button


항공사 
#__next > div > div.container > div.List_content > div > div.selected_schedules > div > div > div.SelectedFlight_summary__1t3j9 > div.SelectedFlight_row__4oIWt > div > b
#__next > div > div.container > div.List_content > div > div.selected_schedules > div > div > div.SelectedFlight_summary__1t3j9 > div.SelectedFlight_row__4oIWt > div > b

시간 
#__next > div > div.container > div.List_content > div > div.selected_schedules > div > div > div.SelectedFlight_summary__1t3j9 > div.SelectedFlight_route__36vfe > div
#__next > div > div.container > div.List_content > div > div.selected_schedules > div > div > div.SelectedFlight_summary__1t3j9 > div.SelectedFlight_route__36vfe > div
가격
#__next > div > div.container > div.List_content > div > div.selected_schedules > div > div > div.SelectedFlight_summary__1t3j9 > div.desc > b > i
#__next > div > div.container > div.List_content > div > div.selected_schedules > div > div > div.SelectedFlight_summary__1t3j9 > div.desc > b > i

# %%
#. selenium으로 네이버 사이트 접속 후 5개 내부사이트로 이동하면서 
# 10개의 요소를 선택 후 출력한 후 드라이버를 클로즈하세요. 
# 텍스트, 링크 포함 ( 텍7 링3 이런식으로)
# 코드를 실행하면 네이버 오픈해주고 옮겨다니면서 요소 뽑아서 가지고있다가 나중에 출력
# + 딛기
# time.sleep써서 사람이 하는거처럼 보이게 하기

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url= 'https://naver.com'
driver =webdriver.Chrome('C:/♥workspace/tool/chromedriver.exe')
driver.get(url)

time.sleep(1)
#사이트1  / 요소2개
driver.find_element_by_xpath('//*[@id="NM_FAVORITE"]/div[1]/ul[2]/li[1]/a').click()

elem1=driver.find_element_by_css_selector('#container > div.view_all.on > div.alldic_wrap.alldic_view > div.view_dic > div.dic_wrap.eu > p')
elem2=driver.find_element_by_css_selector('#container > div.view_all.on > div:nth-child(2) > h3')
time.sleep(2)
print(elem1.text)
time.sleep(2)
print(elem2.text)

driver.back()

time.sleep(1)
#사이트2  / 요소2개
driver.find_element_by_xpath('//*[@id="NM_FAVORITE"]/div[1]/ul[2]/li[3]/a').click()

elem3=driver.find_element_by_css_selector('#container > div.aside > div > div.aside_area.aside_stock > table > tbody > tr:nth-child(1) > th > a').get_attribute("href")
elem4=driver.find_element_by_css_selector('#container > div.aside > div > div.aside_area.aside_stock > table > tbody > tr:nth-child(2) > th > a').get_attribute("href")
time.sleep(2)
print(elem3)
time.sleep(2)
print(elem4)

driver.back()

time.sleep(1)
#사이트3 / 요소2개
driver.find_element_by_xpath('//*[@id="NM_FAVORITE"]/div[1]/ul[1]/li[4]/a').click()

elem5=driver.find_element_by_link_text('코로나 백신 예방접종 예약번호를 잃어버렸는데').get_attribute("href")
elem6=driver.find_element_by_link_text('사회적 거리두기 4단계 헬스장').get_attribute("href")
time.sleep(2)
print(elem5)
time.sleep(2)
print(elem6)

driver.back()


time.sleep(1)
#사이트4/ 요소2개
driver.find_element_by_xpath('//*[@id="NM_FAVORITE"]/div[1]/ul[2]/li[7]/a').click()

elem7=driver.find_element_by_css_selector('#owl > div > div > div:nth-child(1) > a > div > strong')
elem8=driver.find_element_by_css_selector('#owl > div > div > div:nth-child(3) > a > div > strong')
time.sleep(2)
print(elem7.text)
time.sleep(2)
print(elem8.text)

driver.back()


time.sleep(1)
#사이트5/ 요소2개
driver.find_element_by_xpath('//*[@id="NM_FAVORITE"]/div[1]/a').click()

elem9=driver.find_element_by_css_selector('#gnb > div.ly_service > div.group_service.NM_FAVORITE_ALL_LY > dl:nth-child(6) > dd:nth-child(5) > a')
elem10=driver.find_element_by_css_selector('#gnb > div.ly_service > div.group_service.NM_FAVORITE_ALL_LY > dl:nth-child(3) > dd:nth-child(8) > a')
time.sleep(2)
print(elem9.text)
time.sleep(2)
print(elem10.text)

driver.close()
# Out:
# 유럽/아메리카
# 주제백과 바로가기
# https://finance.naver.com/world/sise.nhn?symbol=DJI@DJI&fdtc=0
# https://finance.naver.com/world/sise.nhn?symbol=NAS@IXIC&fdtc=0
# https://kin.naver.com/qna/detail.naver?d1id=7&dirId=7010107&docId=393342517
# https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40607&docId=394161680
# 플리니우스 박물지(세계 최초의 백과사전)(양장본 HardCover)
# 팬데믹 시대에 읽는 동의보감 강의
# MY구독
# 인플루언서 검색

# %% [markdown]
# find_element_by_id:id 속성을 사용하여 접근
#
# find_element(s)_by_class_name: 클래스를 사용하여 접근
#
# find_element(s)_by_name: 속성을 사용하여 접근
#
# find_element(s)_by_xpath: 속성을 사용하여 접근
#
# find_element(s)_by_link_text:앵커태그(a 태그)에 사용되는 텍스트로 접근
#
# find_element(s)_by_partial_link_text:앵커태그(a 태그)에 사용되는 일부 텍스트로 접근
#
# find_element(s)_by_tag_name: 태그를 사용하여 접근
#
# find_element(s)_by_css_selector: CSS선택자를 사용하여 접근
