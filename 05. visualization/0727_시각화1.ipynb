# %%
import pandas as pd
fish_multi= pd.read_csv('dataset/4_fm2.csv')
fish_multi.head()
# Out:
#   species  length
# 0       A       2
# 1       A       3
# 2       A       3
# 3       A       4
# 4       A       4

# %%
import seaborn as sns
sns.boxplot(x='species',y='length',data=fish_multi)
# Out:
# <AxesSubplot:xlabel='species', ylabel='length'>

# %%
fish_multi.groupby('species').describe()
# Out:
#         length
#          count mean       std  min   25%  50%   75%  max
# species
# A         10.0  4.0  1.154701  2.0  3.25  4.0  4.75  6.0
# B         10.0  7.0  1.154701  5.0  6.25  7.0  7.75  9.0

# %%
fish_multi.iloc[5,1]=10
fish_multi.iloc[10,1]=2
fish_multi.groupby('species').describe()
# Out:
#         length
#          count mean       std  min   25%  50%   75%   max
# species
# A         10.0  4.6  2.221111  2.0  3.25  4.0  5.00  10.0
# B         10.0  6.7  1.888562  2.0  6.25  7.0  7.75   9.0

# %%
# 과제 
# Q. A,B 그룹의 Box Plot 을 그리고 이상치를 구하세요.

# %%
# 0부터 1000사이의 균일분포를 이루는 난수 생성

# %%
import numpy as np
data=np.random.rand(10000)*1000
data[:10]
df= pd.DataFrame(data,columns=['Num'])
print(df.head())
df.describe()
# Out:
#           Num
# 0  717.737372
# 1  563.059778
# 2  303.268441
# 3  449.840031
# 4  926.017550
#                 Num
# count  10000.000000
# mean     503.250592
# std      289.470640
# min        0.137025
# 25%      250.719319
# 50%      506.004033
# 75%      751.686687
# max      999.859497

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Q. 평균 0, 표준편차 1인 표준 정규분포 난수 10000개로
# 데이터 프레임을 생성하고 
# 통계 요약표 및 시각화를 수행하세요.(컬럼명'Num')

data= np.random.randn(10000)
df= pd.DataFrame(data,columns=['Num'])
print(df.describe())
print(df.plot(kind='hist',bins=30))
# Out:
#                 Num
# count  10000.000000
# mean       0.004233
# std        1.009802
# min       -4.029157
# 25%       -0.668818
# 50%        0.004633
# 75%        0.687773
# max        4.168304
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
from scipy import stats
np.random.seed(1)
sample1= stats.norm.rvs(loc=10,scale=2,size=1000) #평균10, 표준편차2, 샘플1000개
df1= pd.DataFrame(sample1,columns=['Num'])
print(df1.head())
print(df1.describe)
df1.plot(kind='hist',bins=50)
# Out:
#          Num
# 0  13.248691
# 1   8.776487
# 2   8.943656
# 3   7.854063
# 4  11.730815
# <bound method NDFrame.describe of            Num
# 0    13.248691
# 1     8.776487
# 2     8.943656
# 3     7.854063
# 4    11.730815
# ..         ...
# 995   9.767112
# 996   5.445404
# 997   9.860751
# 998  10.707741
# 999   9.626090
#
# [1000 rows x 1 columns]>
# <AxesSubplot:ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2,1)
data = pd.Series(np.random.rand(16), index = list('abcdefghijklmnop'))
data.plot.bar(ax = axes[0], color = 'k', alpha = 0.3)
data.plot.barh(ax = axes[1], color = 'k', alpha = 0.7)


# alpha는 투명도
# Out:
# <AxesSubplot:>

# %%
df= pd.DataFrame(np.random.rand(6,4),
                index=['one','two','three','four','five','six'],
                columns=['A','B','C','D'])
print(df)
# Out:
#               A         B         C         D
# one    0.067489  0.880539  0.459957  0.763873
# two    0.253889  0.591387  0.428795  0.382101
# three  0.126713  0.244267  0.079342  0.302858
# four   0.741705  0.615016  0.672411  0.008383
# five   0.678377  0.503181  0.230908  0.174897
# six    0.184983  0.844260  0.982590  0.913740

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='barh',stacked=True,alpha=0.8)
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1,21,2)
y = np.array([3,5,6,13,30,21,22,29,33,32])

#plt.figure(fig) >> 그림의 사이즈 정하기
plt.figure(figsize=(8,5))
# marker 는 꼭지점 동글뱅이
plt.plot(x,y,color='blue', marker='o', markersize=5)
plt.title('Lineplot Matplotlib', size=20)
plt.xlabel('x', size=15)
plt.ylabel('y', size=15)

#범례설정 
plt.legend(labels=['lineplot'])

# %%
np.random.seed(0)
x= np.arange(20)
y1= np.arange(20)*2 + np.random.randn(20)*10  # 편차10배줌
y2= np.arange(20)*2 + np.random.randn(20)
plt.figure(figsize=(10,6))
plt.plot(x,y1)
plt.plot(x,y2,color='magenta',marker='o', markersize=5)
plt.xlabel('x',size=20)
plt.ylabel('y',size=20)
plt.title('Line Grapyh',size=30)
plt.legend(['A','B'])

# %%
# 막대 그래프 
y= np.random.randint(2,10,size=10)
x= range(len(y)) # y랑 길이 똑같이
print(x)
print(y)

plt.figure(figsize=(8,4))
plt.bar(x,y,width=0.8,color='skyblue')

plt.ylabel('y')
plt.xlabel('x')
# Out:
# range(0, 10)
# [8 5 7 6 3 4 6 5 6 8]
# Text(0.5, 0, 'x')

# %%
# 과제 - 추가 decoration ( 제목붙여보고 등등...)

# %%
# scatter plot 
df_auto= pd.read_excel('dataset/auto-mpg.xlsx')
x= df_auto.mpg
y= df_auto.weight
plt.figure(figsize=(8,4))
plt.scatter(x,y,color='skyblue')

# %%
# histogram
plt.hist(df_auto.mpg,bins=20,color='pink')
# Out:
# (array([ 3., 10., 40., 38., 36., 37., 30., 31., 21., 33., 24., 24., 20.,
#         18., 13.,  9.,  4.,  1.,  5.,  1.]),
#  array([ 9.  , 10.88, 12.76, 14.64, 16.52, 18.4 , 20.28, 22.16, 24.04,
#         25.92, 27.8 , 29.68, 31.56, 33.44, 35.32, 37.2 , 39.08, 40.96,
#         42.84, 44.72, 46.6 ]),
#  <BarContainer object of 20 artists>)

# %%
fig= plt.figure(figsize=(10,6))
ax1= fig.add_subplot(2,2,1) # 2행2열에 첫번째
ax2= fig.add_subplot(2,2,2)
ax3= fig.add_subplot(2,2,3)
ax4= fig.add_subplot(2,2,4)

ax1.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)

ax2.hist(np.random.randn(100),bins=15,color='pink',alpha=0.7)

# ax2.hist(np.random.rand(100), bins = 20)

x= np.arange(100)
y= np.arange(100) + np.random.randn(100)*20
# ax3.scatter(x,y,color='skyblue')
ax3.plot(x,y,'k--')

# ax3.plot(np.random.randn(50).cumsum(),'k--') #누적 cumsum

ax4.bar(np.arange(10),np.random.randint(15,30, 10))
# Out:
# <BarContainer object of 10 artists>

# %%
# 과제
# Q. 히스토그램 ,선 ,막대 ,산점도 그래프 4개를 서브플롯으로 출력
# 가급적이면 의미있는 데이터

# %%
fig,axes= plt.subplots(2,3,figsize=(20,10))
axes[0,0].hist(np.random.randn(100),bins=50)
axes[0,1].hist(np.random.randn(1000),bins=50)
axes[0,2].hist(np.random.randn(10000),bins=50)
axes[1,0].hist(np.random.randn(100000),bins=50)
axes[1,1].hist(np.random.randn(1000000),bins=50)
axes[1,2].hist(np.random.randn(10000000),bins=50)
# Out:
# (array([1.00000e+00, 0.00000e+00, 5.00000e+00, 1.50000e+01, 4.80000e+01,
#         1.11000e+02, 2.64000e+02, 5.58000e+02, 1.26900e+03, 2.60800e+03,
#         5.10800e+03, 1.00850e+04, 1.82690e+04, 3.20160e+04, 5.34800e+04,
#         8.51630e+04, 1.31429e+05, 1.92552e+05, 2.70144e+05, 3.63031e+05,
#         4.66074e+05, 5.71710e+05, 6.70742e+05, 7.54791e+05, 8.12617e+05,
#         8.37046e+05, 8.25594e+05, 7.77589e+05, 7.02280e+05, 6.06013e+05,
#         4.98701e+05, 3.96557e+05, 2.99758e+05, 2.17032e+05, 1.49850e+05,
#         9.89460e+04, 6.27780e+04, 3.83130e+04, 2.22510e+04, 1.23480e+04,
#         6.60800e+03, 3.25900e+03, 1.61800e+03, 7.60000e+02, 3.68000e+02,
#         1.41000e+02, 6.20000e+01, 2.40000e+01, 8.00000e+00, 6.00000e+00]),
#  array([-5.40015865, -5.1897547 , -4.97935074, -4.76894679, -4.55854284,
#         -4.34813889, -4.13773494, -3.92733099, -3.71692703, -3.50652308,
#         -3.29611913, -3.08571518, -2.87531123, -2.66490727, -2.45450332,
#         -2.24409937, -2.03369542, -1.82329147, -1.61288751, -1.40248356,
#         -1.19207961, -0.98167566, -0.77127171, -0.56086776, -0.3504638 ,
#         -0.14005985,  0.0703441 ,  0.28074805,  0.491152  ,  0.70155596,
#          0.91195991,  1.12236386,  1.33276781,  1.54317176,  1.75357572,
#          1.96397967,  2.17438362,  2.38478757,  2.59519152,  2.80559548,
#          3.01599943,  3.22640338,  3.43680733,  3.64721128,  3.85761523,
#          4.06801919,  4.27842314,  4.48882709,  4.69923104,  4.90963499,
#          5.12003895]),
#  <BarContainer object of 50 artists>)

# %%
fig,axes= plt.subplots(2,2,figsize=(10,8),sharex=True, sharey=True)
#2행2열 10,8사이즈 x/y축 쉐어 

for i in range(2):  #2행2열이라 다중 for문
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins=50,color='k',alpha=0.5)
        
# 간격지정 / adjust: 고정
plt.subplots_adjust(wspace=0.01,hspace=0.01)

# %%
# 색상, 마커, 선스타일 
from numpy.random import randn
np.random.seed(1)
plt.figure(figsize=(10,6))
plt.plot(randn(30).cumsum(),linestyle='dashed',color='blue',marker='o')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
np.random.seed(0)
data= np.random.randn(1000)
cdata= data.cumsum()
print(data[:10])
cdata[:10]
# Out:
# [ 1.76405235  0.40015721  0.97873798  2.2408932   1.86755799 -0.97727788
#   0.95008842 -0.15135721 -0.10321885  0.4105985 ]
# array([1.76405235, 2.16420955, 3.14294754, 5.38384074, 7.25139873,
#        6.27412085, 7.22420927, 7.07285206, 6.96963321, 7.38023171])

# %%
import warnings
warnings.filterwarnings('ignore')
from matplotlib import rc
rc('font',family='Malgun Gothic')  # 한글 안깨지게, 폰트설정
plt.rcParams['axes.unicode_minus']= False # 마이너스 부호 출력 설정


fig= plt.figure(figsize=(12,6))
ax= fig.add_subplot(1,1,1)
ax.plot(cdata)

ticks= ax.set_xticks([0,250,500,750,1000])
labels= ax.set_xticklabels(['one','two','three','four','five'],
                         rotation=30,fontsize='small')

ax.set_title('제목,축이름,눈금,눈금 이름 설정', size=30)
ax.set_xlabel('Stages',size=20)
ax.set_ylabel('Sum',size=20)
# Out:
# Text(0, 0.5, 'Sum')

# %%
from numpy.random import randn

fig= plt.figure(figsize=(10,6))
ax= fig.add_subplot(1,1,1) # 하나의 그래프

#import 를 randn으로 해줘서 이렇게만 써도됨
ax.plot(randn(1000).cumsum(),'m', label='one') 
ax.plot(randn(1000).cumsum(),'g', label='two') 
ax.plot(randn(1000).cumsum(),'b', label='three') 

plt.legend(loc='best') # loc= location


# 주석 달 수 있음 . - 알아보기...

# %%
# 나이 카테고리 만들어서 카테고리별 파이차트 
def get_age_cat(age):
    cat=''
    if age<15: cat='young'
    elif age<30: cat='teen'
    elif age<45: cat='adult'
    elif age<60: cat='mature'
    else: cat='elder'
    return cat

df['age_cat']=df['age'].apply(lambda x: get_age_cat(x))
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone age_cat
# 0    man        True  NaN  Southampton    no  False    teen
# 1  woman       False    C    Cherbourg   yes  False   adult
# 2  woman       False  NaN  Southampton   yes   True    teen
# 3  woman       False    C  Southampton   yes  False   adult
# 4    man        True  NaN  Southampton    no   True   adult

# %%
df['Ratio']=1
df_age_cat= df.groupby('age_cat').sum()
df_age_cat
df_age_cat.Ratio.plot(kind='pie',
                     figsize=(10,8),
                     autopct='%.2f%%', #autopercent 포멧사용
                     startangle=0)
plt.title('Age Category', size=20)
plt.axis('equal')
plt.legend(labels=df_age_cat.index,loc='best')

# %%
import seaborn as sns
df= sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 과제
# Q. 시각화 탐색을 통하여 df의 각 칼럼에 대한 인사이트를 5개 이상 도출 

- 의미없는 변수 제거
- 종속변수인 survived와 독립변수간 상관관계
- 독립변수간 상관관계 
- 분석에 의미있는 파생변수 도출 
-
