# %%
import pandas as pd
df= pd.read_csv('dataset/강원도인구.csv',index_col=0,encoding='cp949')

df
# Out:
#          읍면동별(2)      2018    2018.1    2018.2    2018.3   2018.4   2018.5  \
# 읍면동별(1)
# 읍면동별(1)  읍면동별(2)  세대수 (세대)  등록인구 (명)  등록인구 (명)  등록인구 (명)  한국인 (명)  한국인 (명)
# 읍면동별(1)  읍면동별(2)        소계        소계         남         여       소계        남
# 전체            소계    707245   1561313    786364    774949  1543052   776456
# 춘천시           소계    120190    285002    140527    144475   280640   138243
# 춘천시          신북읍      3472      8080      4059      4021     7949     3994
# ...          ...       ...       ...       ...       ...      ...      ...
# 양양군           서면      1526      3017      1557      1460     3005     1551
# 양양군          손양면      1240      2485      1273      1212     2426     1238
# 양양군          현북면      1463      2648      1373      1275     2612     1344
# 양양군          현남면      1704      3135      1604      1531     3081     1562
# 양양군          강현면      2306      4423      2237      2186     4385     2228
#
#           2018.6   2018.7   2018.8   2018.9        2018.10
# ...
