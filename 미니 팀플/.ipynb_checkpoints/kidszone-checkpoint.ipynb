# %%
import pandas as pd
import numpy as np

df = pd.read_excel('dataset/전국어린이보호구역표준데이터-20210801.xls')
df.columns = df.iloc[0]
df = df.iloc[1:]

# %%
# def seoul(x):
#     import re

#     p = re.compile('서울')

#     r = p.findall(x)
    
#     return ''.join(r)
# df['제공기관명'] = df.제공기관명.apply(seoul)

# df = df[(df['제공기관명']=='서울특별시')]

df = df.loc[df.loc[:,'제공기관명'].str.contains('서울',na=False)]

# %%
df1 = df[(df['소재지지번주소'].isnull()==True)].copy()
df1
# Out:
# 0      시설종류     대상시설명                      소재지도로명주소 소재지지번주소           위도  \
# 558    어린이집  구민회관어린이집             서울특별시 강남구 삼성로 154     NaN    37.493887
# 559    어린이집    신사어린이집          서울특별시 강남구 도산대로56길 14     NaN  37.52212074
# 560    어린이집   보미나어린이집           서울특별시 강남구 학동로20길 25     NaN  37.51150308
# 561    어린이집    청담어린이집          서울특별시 강남구 도산대로56길 14     NaN  37.52212074
# 562    어린이집    역삼어린이집          서울특별시 강남구 테헤란로22길 46     NaN    37.497106
# ...     ...       ...                           ...     ...          ...
# 16563  어린이집    선재어린이집           서울특별시 강남구 삼성로71길 31     NaN  37.50147751
# 16564  어린이집    성아어린이집           서울특별시 강남구 논현로32길 16     NaN    37.484042
# 16565  어린이집    청수어린이집          서울특별시 강남구 압구정로79길 26     NaN    37.525052
# 16566  어린이집  튼튼영재어린이집  서울특별시 강남구 학동로101길 26, 삼익상가3층     NaN  37.52244507
# 16567  어린이집  강남구청어린이집             서울특별시 강남구 학동로 426     NaN  37.51796636
#
# 0               경도       관리기관명 관할경찰서명 CCTV설치여부 CCTV설치대수 보호구역도로폭     데이터기준일자  \
# 558    127.0642704  서울특별시 강남구청  수서경찰서        Y        1      30  2021-06-28
# 559    127.0401134  서울특별시 강남구청  강남경찰서        Y        1       6  2021-06-28
# 560    127.0285346  서울특별시 강남구청  강남경찰서        Y        1       8  2021-06-28
# 561    127.0401134  서울특별시 강남구청  강남경찰서        Y        1       6  2021-06-28
# 562     127.035679  서울특별시 강남구청  수서경찰서        Y        1       6  2021-06-28
# ...            ...         ...    ...      ...      ...     ...         ...
# 16563  127.0563559  서울특별시 강남구청  수서경찰서        Y        1       6  2021-06-28
# 16564   127.043583  서울특별시 강남구청  수서경찰서        Y        1       6  2021-06-28
# 16565   127.049284  서울특별시 강남구청  강남경찰서        Y        3       8  2021-06-28
# 16566  127.0576206  서울특별시 강남구청  강남경찰서        Y        3       6  2021-06-28
# 16567  127.0470611  서울특별시 강남구청  강남경찰서        Y        1       8  2021-06-28
#
# 0       제공기관코드      제공기관명
# 558    3220000  서울특별시 강남구
# 559    3220000  서울특별시 강남구
# 560    3220000  서울특별시 강남구
# 561    3220000  서울특별시 강남구
# 562    3220000  서울특별시 강남구
# ...        ...        ...
# 16563  3220000  서울특별시 강남구
# 16564  3220000  서울특별시 강남구
# 16565  3220000  서울특별시 강남구
# 16566  3220000  서울특별시 강남구
# 16567  3220000  서울특별시 강남구
#
# [431 rows x 14 columns]

# %%
import requests
import json
import numpy as np


addrs = list(df1['소재지도로명주소'])
locations = []


for addr in addrs:
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query={}'.format(addr)
    headers = {
        "Authorization" : "KakaoAK ec276bf4e2dcd1c5055b2da48ef1b6f7"}
    place = requests.get(url, headers = headers).json()['documents']
    locations.append(place)
    
city = []
town = []

for i in range(len(locations)):
    
    try:
        city.append(locations[i][0].get('address').get('region_2depth_name'))
        town.append(locations[i][0].get('address').get('region_3depth_name'))
        
    except IndexError:
        print(i,'번째 주소 못가져옴',end ='')
        print()
        city.append('없음')
        town.append('없음')
        
    except AttributeError:
        city.append(locations[i][0].get('road_address').get('region_2depth_name'))
        town.append(locations[i][0].get('road_address').get('region_3depth_name'))


city_town = np.array([city,town]).T
df_temp = pd.DataFrame(city_town, columns = ['2', '3'])
# asan['소재지지번주소'] = df_temp[['3']]
# asan['소재지지번주소'] = df_temp[['3']]
# Out:
# 87 번째 주소 못가져옴
# 100 번째 주소 못가져옴
# 126 번째 주소 못가져옴

# %%
a = pd.DataFrame(city_town, columns = ['구','동'])
a['소재지지번주소'] = a[['구','동']].agg(' '.join,axis=1)

# %%
a.drop(['구','동'],axis=1,inplace=True)

# %%
len(list(a['소재지지번주소']))
# Out:
# 431

# %%
df1['소재지지번주소'] = list(a['소재지지번주소'])

# %%
df1.loc[8042,'소재지지번주소'] = '강남구 개포2동'
df1.loc[8055,'소재지지번주소'] = '강남구 개포2동'
df1.loc[8081,'소재지지번주소'] = '도봉구 도봉1동'

# %%
# df1.drop('Unnamed: 0',axis=1,inplace=True)

df1.to_csv('dataset/서울_어린이보호구역_주소O.csv')

a = pd.read_csv('dataset/서울_어린이보호구역_주소O.csv')
a.제공기관명.unique()
# Out:
# array(['서울특별시 강남구', '서울특별시 도봉구', '서울특별시 강서구', '서울특별시 관악구', '서울특별시 은평구',
#        '서울특별시 구로구'], dtype=object)
