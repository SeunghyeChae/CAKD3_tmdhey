# %%
import pandas as pd
import numpy as np

df = pd.read_excel('dataset/전국어린이보호구역표준데이터-20210801.xls')
df.columns = df.iloc[0]
df = df.iloc[1:]

# %%
# def seoul(x):
#     import re

#     p = re.compile('서울')

#     r = p.findall(x)
    
#     return ''.join(r)
# df['제공기관명'] = df.제공기관명.apply(seoul)

# df = df[(df['제공기관명']=='서울특별시')]

df = df.loc[df.loc[:,'제공기관명'].str.contains('서울',na=False)]

# %%
df1 = df[(df['소재지지번주소'].isnull()==True)].copy()
df1
# Out:
# 0      시설종류     대상시설명                      소재지도로명주소 소재지지번주소           위도  \
# 558    어린이집  구민회관어린이집             서울특별시 강남구 삼성로 154     NaN    37.493887
# 559    어린이집    신사어린이집          서울특별시 강남구 도산대로56길 14     NaN  37.52212074
# 560    어린이집   보미나어린이집           서울특별시 강남구 학동로20길 25     NaN  37.51150308
# 561    어린이집    청담어린이집          서울특별시 강남구 도산대로56길 14     NaN  37.52212074
# 562    어린이집    역삼어린이집          서울특별시 강남구 테헤란로22길 46     NaN    37.497106
# ...     ...       ...                           ...     ...          ...
# 16563  어린이집    선재어린이집           서울특별시 강남구 삼성로71길 31     NaN  37.50147751
# 16564  어린이집    성아어린이집           서울특별시 강남구 논현로32길 16     NaN    37.484042
# 16565  어린이집    청수어린이집          서울특별시 강남구 압구정로79길 26     NaN    37.525052
# 16566  어린이집  튼튼영재어린이집  서울특별시 강남구 학동로101길 26, 삼익상가3층     NaN  37.52244507
# 16567  어린이집  강남구청어린이집             서울특별시 강남구 학동로 426     NaN  37.51796636
#
# 0               경도       관리기관명 관할경찰서명 CCTV설치여부 CCTV설치대수 보호구역도로폭     데이터기준일자  \
# 558    127.0642704  서울특별시 강남구청  수서경찰서        Y        1      30  2021-06-28
# 559    127.0401134  서울특별시 강남구청  강남경찰서        Y        1       6  2021-06-28
# 560    127.0285346  서울특별시 강남구청  강남경찰서        Y        1       8  2021-06-28
# 561    127.0401134  서울특별시 강남구청  강남경찰서        Y        1       6  2021-06-28
# 562     127.035679  서울특별시 강남구청  수서경찰서        Y        1       6  2021-06-28
# ...            ...         ...    ...      ...      ...     ...         ...
# 16563  127.0563559  서울특별시 강남구청  수서경찰서        Y        1       6  2021-06-28
# 16564   127.043583  서울특별시 강남구청  수서경찰서        Y        1       6  2021-06-28
# 16565   127.049284  서울특별시 강남구청  강남경찰서        Y        3       8  2021-06-28
# 16566  127.0576206  서울특별시 강남구청  강남경찰서        Y        3       6  2021-06-28
# 16567  127.0470611  서울특별시 강남구청  강남경찰서        Y        1       8  2021-06-28
#
# 0       제공기관코드      제공기관명
# 558    3220000  서울특별시 강남구
# 559    3220000  서울특별시 강남구
# 560    3220000  서울특별시 강남구
# 561    3220000  서울특별시 강남구
# 562    3220000  서울특별시 강남구
# ...        ...        ...
# 16563  3220000  서울특별시 강남구
# 16564  3220000  서울특별시 강남구
# 16565  3220000  서울특별시 강남구
# 16566  3220000  서울특별시 강남구
# 16567  3220000  서울특별시 강남구
#
# [431 rows x 14 columns]

# %%
df2 = df[(df['소재지지번주소'].isnull()==False)].copy()
df2
# Out:
# 0      시설종류        대상시설명               소재지도로명주소                소재지지번주소  \
# 432    초등학교  청파초교(병설유치원)     서울특벽시 용산구 효창원로 228   서울특별시 용산구 청파동2가 1-42
# 433    어린이집    강동복지관어린이집    서울특별시 강동구 진황도로23길 7     서울특별시 강동구 천호3동 555
# 434    어린이집    올리브나무어린이집  서울특별시 강동구 양재대로134길 41  서울특별시 강동구 명일1동 338-19
# 435    어린이집    자이젠킨더어린이집  서울특별시 강동구 천호대로199길 25     서울특별시 강동구 길동 123-2
# 436    어린이집    강동무지개어린이집  서울특별시 강동구 양재대로125길 30    서울특별시 강동구 천호동 43-22
# ...     ...          ...                    ...                    ...
# 17531   유치원      방배병설유치원  서울특별시 서초구 방배중앙로13길 26    서울특별시 서초구 방배동 861-1
# 17532   유치원       새성민유치원      서울특별시 서초구 효령로 110    서울특별시 서초구 방배동 981-2
# 17533   유치원        새순유치원   서울특별시 서초구 서초대로15길 57   서울특별시 서초구 방배동 831-12
# 17534   유치원      서래병설유치원      서울특별시 서초구 방배로 260     서울특별시 서초구 방배본동 771
# 17535   유치원     서울청계숲유치원   서울특별시 서초구 청계산로11길 14      서울특별시 서초구 신원동 247
#
# 0                 위도              경도       관리기관명 관할경찰서명 CCTV설치여부 CCTV설치대수  \
# 432    37.5473030994  126.9635440384        용산구청  용산경찰서        Y      NaN
# 433    37.5400428356     127.1297892  서울특별시 강동구청  강동경찰서        Y        1
# 434       37.5478059     127.1459154  서울특별시 강동구청  강동경찰서        Y        1
# 435       37.5377155     127.1478568  서울특별시 강동구청  강동경찰서        Y        1
# 436    37.5446048382     127.1406641  서울특별시 강동구청  강동경찰서        Y        1
# ...              ...             ...         ...    ...      ...      ...
# 17531    37.48676419     126.9871372     서울시 서초구  방배경찰서        Y        1
# 17532     37.4806567     126.9961191     서울시 서초구  방배경찰서        Y        1
# 17533    37.48906371     126.9885796     서울시 서초구  방배경찰서        Y        1
# 17534    37.49640526     126.9901572     서울시 서초구  방배경찰서        Y        1
# 17535      37.447737     127.0577441     서울시 서초구  서초경찰서        Y        1
#
# 0     보호구역도로폭     데이터기준일자   제공기관코드      제공기관명
# 432      4~12  2020-02-18  3020000  서울특별시 용산구
# 433         6  2020-09-11  3240000  서울특별시 강동구
# 434         6  2020-09-11  3240000  서울특별시 강동구
# 435         5  2020-09-11  3240000  서울특별시 강동구
# 436         6  2020-09-11  3240000  서울특별시 강동구
# ...       ...         ...      ...        ...
# 17531       1  2020-07-01  3210000  서울특별시 서초구
# 17532       1  2020-07-01  3210000  서울특별시 서초구
# 17533       1  2020-07-01  3210000  서울특별시 서초구
# 17534       1  2020-07-01  3210000  서울특별시 서초구
# 17535       1  2020-07-01  3210000  서울특별시 서초구
#
# [1215 rows x 14 columns]

# %%
import requests
import json
import numpy as np


addrs = list(df1['소재지도로명주소'])
locations = []


for addr in addrs:
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query={}'.format(addr)
    headers = {
        "Authorization" : "KakaoAK ec276bf4e2dcd1c5055b2da48ef1b6f7"}
    place = requests.get(url, headers = headers).json()['documents']
    locations.append(place)
    
city = []
town = []

for i in range(len(locations)):
    
    try:
        city.append(locations[i][0].get('address').get('region_2depth_name'))
        town.append(locations[i][0].get('address').get('region_3depth_name'))
        
    except IndexError:
        print(i,'번째 주소 못가져옴',end ='')
        print()
        city.append('없음')
        town.append('없음')
        
    except AttributeError:
        city.append(locations[i][0].get('road_address').get('region_2depth_name'))
        town.append(locations[i][0].get('road_address').get('region_3depth_name'))


city_town = np.array([city,town]).T
df_temp = pd.DataFrame(city_town, columns = ['2', '3'])
# asan['소재지지번주소'] = df_temp[['3']]
# asan['소재지지번주소'] = df_temp[['3']]
# Out:
# 87 번째 주소 못가져옴
# 100 번째 주소 못가져옴
# 126 번째 주소 못가져옴

# %%
a = pd.DataFrame(city_town, columns = ['구','동'])
a['소재지지번주소'] = a[['구','동']].agg(' '.join,axis=1)

# %%
a.drop(['구','동'],axis=1,inplace=True)

# %%
len(list(a['소재지지번주소']))
# Out:
# 431

# %%
df1['소재지지번주소'] = list(a['소재지지번주소'])

# %%
df1.loc[8042,'소재지지번주소'] = '강남구 개포2동'
df1.loc[8055,'소재지지번주소'] = '강남구 개포2동'
df1.loc[8081,'소재지지번주소'] = '도봉구 도봉1동'

# %%
result2 = pd.concat([df1,df2], ignore_index=True)

# %%
result2.to_csv('dataset/서울_어린이보호구역.csv)
a = pd.read_csv('dataset/서울_어린이보호구역_주소O.csv')
a
# Out:
#       Unnamed: 0  시설종류     대상시설명               소재지도로명주소               소재지지번주소  \
# 0              0  어린이집  구민회관어린이집      서울특별시 강남구 삼성로 154               강남구 대치동
# 1              1  어린이집    신사어린이집   서울특별시 강남구 도산대로56길 14               강남구 청담동
# 2              2  어린이집   보미나어린이집    서울특별시 강남구 학동로20길 25               강남구 논현동
# 3              3  어린이집    청담어린이집   서울특별시 강남구 도산대로56길 14               강남구 청담동
# 4              4  어린이집    역삼어린이집   서울특별시 강남구 테헤란로22길 46               강남구 역삼동
# ...          ...   ...       ...                    ...                   ...
# 1641        1641   유치원   방배병설유치원  서울특별시 서초구 방배중앙로13길 26   서울특별시 서초구 방배동 861-1
# 1642        1642   유치원    새성민유치원      서울특별시 서초구 효령로 110   서울특별시 서초구 방배동 981-2
# 1643        1643   유치원     새순유치원   서울특별시 서초구 서초대로15길 57  서울특별시 서초구 방배동 831-12
# 1644        1644   유치원   서래병설유치원      서울특별시 서초구 방배로 260    서울특별시 서초구 방배본동 771
# 1645        1645   유치원  서울청계숲유치원   서울특별시 서초구 청계산로11길 14     서울특별시 서초구 신원동 247
#
#              위도          경도       관리기관명 관할경찰서명 CCTV설치여부  CCTV설치대수 보호구역도로폭  \
# 0     37.493887  127.064270  서울특별시 강남구청  수서경찰서        Y       1.0      30
# 1     37.522121  127.040113  서울특별시 강남구청  강남경찰서        Y       1.0       6
# 2     37.511503  127.028535  서울특별시 강남구청  강남경찰서        Y       1.0       8
# 3     37.522121  127.040113  서울특별시 강남구청  강남경찰서        Y       1.0       6
# 4     37.497106  127.035679  서울특별시 강남구청  수서경찰서        Y       1.0       6
# ...         ...         ...         ...    ...      ...       ...     ...
# 1641  37.486764  126.987137     서울시 서초구  방배경찰서        Y       1.0       1
# 1642  37.480657  126.996119     서울시 서초구  방배경찰서        Y       1.0       1
# 1643  37.489064  126.988580     서울시 서초구  방배경찰서        Y       1.0       1
# 1644  37.496405  126.990157     서울시 서초구  방배경찰서        Y       1.0       1
# 1645  37.447737  127.057744     서울시 서초구  서초경찰서        Y       1.0       1
#
#          데이터기준일자   제공기관코드      제공기관명
# 0     2021-06-28  3220000  서울특별시 강남구
# 1     2021-06-28  3220000  서울특별시 강남구
# 2     2021-06-28  3220000  서울특별시 강남구
# 3     2021-06-28  3220000  서울특별시 강남구
# 4     2021-06-28  3220000  서울특별시 강남구
# ...          ...      ...        ...
# 1641  2020-07-01  3210000  서울특별시 서초구
# 1642  2020-07-01  3210000  서울특별시 서초구
# 1643  2020-07-01  3210000  서울특별시 서초구
# 1644  2020-07-01  3210000  서울특별시 서초구
# 1645  2020-07-01  3210000  서울특별시 서초구
#
# [1646 rows x 15 columns]
