# %% [markdown]
# ## 빅데이터 기반 AI 응용 솔루션 개발자 전문 과정
#
# #### 교과목명 : 머신러닝 알고리즘 구현
# - 평가일 : 09.03
# - 성명 : 채승혜
# - 점수 : 100

# %% [markdown]
# Q1. iris data를 불러와서 아래 사항을 수행하세요.
# - 붓꽃의 종류를 분류하는 결정트리 알고리즘을 사용하여 모델링 및 정확도로 평가를 수행하세요(test_size = 0.2)
# - 결정트리 모델을 시각화하고 주요한 인사이트를 기술하세요.(tree.plot_tree or tree.export_graphviz 이용)
# - Feature importance를 추출하고 시각화하세요.

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
iris_df= pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['class']= iris.target
iris_df.head(2)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
#
#    class
# 0      0
# 1      0

# %%
iris_df['class'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: class, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.tree import DecisionTreeClassifier


X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, 
                                                    test_size=0.2, random_state=156)
dt= DecisionTreeClassifier()
dt.fit(X_train,y_train)
y_pred= dt.predict(X_test)

accuracy= accuracy_score(y_test,y_pred)
print('정확도>> ',accuracy.round(4))
# Out:
# 정확도>>  0.9667

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize = (10,10))
plot_tree(dt, feature_names = iris.feature_names, 
          class_names = iris.target_names, max_depth=5)
plt.show()

# %%
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

ftr_importance_= dt.feature_importances_
ftr_importance_series = pd.Series(ftr_importance_,index=iris.feature_names )

fig, axs = plt.subplots(figsize=(8,8),nrows=1, ncols=1)
fig.tight_layout
axs.set_title('DecisiontreeClassifier Feature importance')
sns.barplot(x=ftr_importance_series, y= ftr_importance_series.index)
# Out:
# <AxesSubplot:title={'center':'DecisiontreeClassifier Feature importance'}>

# %% [markdown]
# Q2. 신용카드 사기 검출 분류문제를 아래와 같이 수행하세요.
# - 'dataset/creditcard.csv'를 불러와서 출력하세요
# - 인자로 입력받은 DataFrame을 복사한 뒤 Time 칼럼만 삭제하고 복사된 df 반환하는 사용자 함수 생성
# - 사전 데이터 가공 후 학습과 테스트 데이터 세트를 반환하는 함수(테스트 사이즈 0.3)
# - 오차행렬, 정확도, 정밀도, 재현율, f1, AUC 평가 함수
# - 로지스틱 리그레션을 적용한 모델 학습 및 사용자 함수를 이용하여 평가
# - 인자로 사이킷런의 Estimator 객체와 학습/테스트 데이터 세트를 입력 받아서 학습/예측/평가 수행하는 사용자 함수 생성
# - 사용자 함수를 사용하여 LightGBM으로 모델을 학습한 뒤 별도의 테스트 데이터 세트에서 예측 평가를 수행.
#   단, n_estimators=1000, num_leaves=64 적용
#   ※ 레이블 값이 극도로 불균형한 분포를 가지고 있는 경우 boost_from_average=False로 파라미터 설정(default=True). default 설정은 재현율, AUC 성능을 매우 크게 저하시킴
# - 넘파이의 np.log1p( )를 이용하여 Amount를 로그 변환하는 사용자 함수 생성
# - Amount를 로그 변환 후 로지스틱 회귀 및 LightGBM 수행.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

card_df = pd.read_csv('dataset/creditcard.csv')
card_df.head(2)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
#
# [2 rows x 31 columns]

# %%
def get_preprocessing_data(df):
    df_copy = df.copy()
    df_copy.drop('Time', axis = 1, inplace = True)
    return df_copy

# %%
from sklearn.metrics import confusion_matrix,accuracy_score, precision_score,\
recall_score,f1_score, roc_auc_score

def get_train_test_dataset(df):
    df = get_preprocessing_data(df)
    X_features = df.iloc[:,:-1]
    y_target = df.iloc[:,-1]
    X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, 
                                                        test_size = 0.3, random_state = 156, stratify = y_target)
    return X_train, X_test, y_train, y_test

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

def get_eval_score(y_test, y_pred, y_pred_proba):
    confusion = confusion_matrix(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred_proba)
    print('오차 행렬\n',confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC_AUC: {4:.4f}'\
          .format(accuracy,precision,recall,f1,roc_auc))

# %%
from sklearn.linear_model import LogisticRegression
import warnings 
warnings.filterwarnings('ignore')

lr = LogisticRegression(random_state = 156)
X_train, X_test, y_train, y_test = get_train_test_dataset(card_df)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
y_pred_proba = lr.predict_proba(X_test)[:,1]
get_eval_score(y_test, y_pred, y_pred_proba)
# Out:
# 오차 행렬
#  [[85285    10]
#  [   70    78]]
# 정확도: 0.9991, 정밀도: 0.8864, 재현율: 0.5270, F1: 0.6610, ROC_AUC: 0.9427

# %%
def get_model_eval(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:,1]
    get_eval_score(y_test, y_pred, y_pred_proba)

# %%
from lightgbm import LGBMClassifier
lgbm_clf = LGBMClassifier(n_estimators = 1000, num_leaves = 64, 
                          boost_from_average = False)
get_model_eval(lgbm_clf, X_train, X_test, y_train, y_test)
# Out:
# 오차 행렬
#  [[85286     9]
#  [   39   109]]
# 정확도: 0.9994, 정밀도: 0.9237, 재현율: 0.7365, F1: 0.8195, ROC_AUC: 0.9653

# %%
def preprocessing(df):
    df_copy = df.copy()
    df_copy.drop('Time', axis = 1, inplace = True)
    df['Amount'] = np.log1p(df['Amount'])
    return df_copy
def get_train_test_dataset(df):
    df = preprocessing(df)
    # 독립변수, 종속변수 구분
    X_features = df.iloc[:,:-1]
    y_target = df.iloc[:,-1]
    X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, test_size = 0.3, random_state = 156, stratify = y_target)
    return X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = get_train_test_dataset(card_df)
print('<<< 로지스틱 회귀 >>>')
get_model_eval(lr_clf, X_train, X_test, y_train, y_test)
print('<<<LightGBM >>>')
get_model_eval(lgbm_clf, X_train, X_test, y_train, y_test)
# Out:
# <<< 로지스틱 회귀 >>>
# 오차 행렬
#  [[85285    10]
#  [   70    78]]
# 정확도: 0.9991, 정밀도: 0.8864, 재현율: 0.5270, F1: 0.6610, ROC_AUC: 0.9430
# <<<LightGBM >>>
# 오차 행렬
#  [[85286     9]
#  [   39   109]]
# 정확도: 0.9994, 정밀도: 0.9237, 재현율: 0.7365, F1: 0.8195, ROC_AUC: 0.9653

# %% [markdown]
# Q3. Q2 신용카드 사기 검출 분류문제에서 아래를 참고하여 이상치 데이터를 제거하고 모델 학습/예측/평가를 수행하세요.
# - 히트맵을 이용해 레이블과의 상관성을 시각화
# - 레이블과 상관성이 높은 피처를 위주로 이상치 검출하는 사용자 함수 생성
# - 사용자 함수를 이용하여 이상치 검출
# - 이상치 제거 사용자 함수를 이용하여 이상치 제거 후 로지스틱 회귀 및 LightGBM 수행 및 평가

# %%
plt.figure(figsize = (20,15))
sns.heatmap(card_df.corr(), annot = True, fmt = '.1g')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Q4. 신용카드 사기검출 분류문제를 SMOTE 오버 샘플링 적용 후 LightGBM 모델을 이용하여 학습, 예측, 평가를 수행하세요.

# %% [markdown]
# Q5. 사이킷런에서 제공해주는 load_boston 데이터셋을 가져와서 아래 사항을 수행하세요.
# - 데이터셋의 타겟 이름을 'PRICE'로 지정한 후 데이터프레임을 생성 pickle 파일('dataset/house_df.pkl')로 저장 후 다시 불어오세요.
# - 히트맵을 이용하여 타겟과 상관관계가 높은 독립 변수를 선택하세요.
# - 종속변수를 로그 변환하세요
# - 위의 사항을 반영하여 선형회귀 모델을 생성 후 평가하고 회귀계수를 출력하세요.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_boston

house= load_boston()
house.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
house_df= pd.DataFrame(house.data, columns=house.feature_names)

house_df.to_pickle('dataset/house_df.pkl')
house_df= pd.read_pickle('dataset/house_df.pkl')
house_df['PRICE']= house.target
house_df.head(2)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO      B  LSTAT  PRICE
# 0     15.3  396.9   4.98   24.0
# 1     17.8  396.9   9.14   21.6

# %%
house_corr= house_df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(house_corr, annot=True, fmt='.1g' )
# Out:
# <AxesSubplot:>

# %%
X_features = house_df[['CRIM','ZN','RM','INDUS' ,'NOX','AGE','LSTAT','RAD', 'PTRATIO']]
y_target = house_df['PRICE']

# %%
house_df['PRICE'] = np.log1p(house_df['PRICE'])

# %%
y_target = house_df['PRICE'] # log변환된 y 
X_features = house_df.drop(['PRICE'],axis=1)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error


X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, 
                                                    test_size=0.2, random_state=156)

lr = LinearRegression()
lr.fit(X_train,y_train)

pred = lr.predict(X_test)
mse = mean_squared_error(y_test,pred)
rmse = np.sqrt(mse)
print('RMSE(RMSLE)>>',rmse.round(3))
# Out:
# RMSE(RMSLE)>> 0.181

# %%
coef= pd.Series(lr.coef_, index=X_features.columns)

print(coef.sort_values(ascending=False))
# Out:
# CHAS       0.095596
# RM         0.076931
# RAD        0.014101
# INDUS      0.002515
# ZN         0.001762
# B          0.000335
# AGE        0.000216
# TAX       -0.000560
# CRIM      -0.011868
# LSTAT     -0.027051
# PTRATIO   -0.034332
# DIS       -0.055917
# NOX       -0.842321
# dtype: float64

# %% [markdown]
# Q6. Q5에서 cv=5를 적용하여 cross_val_score를 이용한 교차검증을 수행하여 5 folds의 평균 RSME를 구하세요.

# %%
from sklearn.model_selection import cross_val_score

cross_score = cross_val_score(lr, X_features,y_target,
                                      scoring='neg_mean_squared_error', cv=5) 
rmse_score = np.sqrt(-1*cross_score)
rmse_avg = np.mean(rmse_score) 

print('5folds CV RMSE 값 :: {0}'.format(rmse_score.round(4)))
print('5folds CV 평균 RMSE 값 :: {0}'.format(rmse_avg.round(4)))
# Out:
# 5folds CV RMSE 값 :: [0.1323 0.1893 0.1657 0.3168 0.229 ]
# 5folds CV 평균 RMSE 값 :: 0.2066

# %% [markdown]
# Q7. load_boston('dataset/house_df.pkl') 데이터셋을 불러와서 아래사항을 수행하세요.
# - alphas = [0, 0.1, 1, 10, 100] 를 적용하여 Ridge 회귀 모델링 및 교차 검증 수행 후 5 폴드 평균 RMSE 출력
# - lasso_alphas = [0.07,0.1,0.5,1,3] 를 적용, Lasso 회귀 모델링 및 교차 검증 수행 후 5 폴드 평균 RMSE 출력(def get_linear_reg_eval(model_name,params=None,X_data_n=None, y_target_n=None, verbose=True 사용자 함수 이용)
# - elastic_alphas = [0.07,0.1,0.5,1,3] 를 적용, ElasticNet 회귀 모델링 및 교차검증 후 5 폴드 평균 RMSE를 출력(사용자 함수 이용)

# %%
house_df= pd.read_pickle('dataset/house_df.pkl')
house_df['PRICE']= house.target
house_df.head(2)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO      B  LSTAT  PRICE
# 0     15.3  396.9   4.98   24.0
# 1     17.8  396.9   9.14   21.6

# %%
y_target = house_df['PRICE']
X_features = house_df.drop(['PRICE'],axis=1)

X_train,X_test,y_train,y_test = train_test_split(X_features,y_target,
                                                 test_size=0.3,random_state=156)

# %%
alphas = [0,0.1,1,10,100]
for a in alphas:
    ridge = Ridge(alpha=a)
    neg_mse = cross_val_score(ridge,X_features,y_target, 
                              scoring='neg_mean_squared_error',cv=5)
    avg_rmse = np.mean(np.sqrt(-1*neg_mse))
    print('alpha {}일 때 5 folds의 평균 RMSE: {:.4f}'.format(a,avg_rmse))
# Out:
# alpha 0일 때 5 folds의 평균 RMSE: 5.8287
# alpha 0.1일 때 5 folds의 평균 RMSE: 5.7885
# alpha 1일 때 5 folds의 평균 RMSE: 5.6526
# alpha 10일 때 5 folds의 평균 RMSE: 5.5182
# alpha 100일 때 5 folds의 평균 RMSE: 5.3296

# %%
def get_linear_eval(model_name, params=None, X_data_n=None, y_target_n=None, verbose=True):
    coef_df = pd.DataFrame()
    if verbose : print('<<<',model_name,'>>>')
    
    for p in params:
        if model_name == 'Ridge': model = Ridge(alpha=p)
        elif model_name == 'Lasso': model = Lasso(alpha=p)
        elif model_name == 'ElasticNet': model = ElasticNet(alpha=p)
        
        neg_mean_scores = cross_val_score(model,X_data_n,y_target_n,
                                          scoring='neg_mean_squared_error',cv=5)
        avg_rmse = np.mean(np.sqrt(-1*neg_mean_scores))
        
        print('alpha {}일 때 5 폴드 세트의 평균 RMSE: {:.4f}'.format(p,avg_rmse))

# %%
lasso_alphas= [0.07,0.1,0.5,1,3]

# %%
get_linear_eval('Lasso',params=lasso_alphas,
                X_data_n=X_features, y_target_n=y_target)
# Out:
# <<< Lasso >>>
# alpha 0.07일 때 5 폴드 세트의 평균 RMSE: 5.6123
# alpha 0.1일 때 5 폴드 세트의 평균 RMSE: 5.6151
# alpha 0.5일 때 5 폴드 세트의 평균 RMSE: 5.6691
# alpha 1일 때 5 폴드 세트의 평균 RMSE: 5.7760
# alpha 3일 때 5 폴드 세트의 평균 RMSE: 6.1888

# %%
Ela_alphas = [0.07,0.1,0.5,1,3]
get_linear_eval('ElasticNet',params=Ela_alphas,
                X_data_n=X_features,y_target_n=y_target)
# Out:
# <<< ElasticNet >>>
# alpha 0.07일 때 5 폴드 세트의 평균 RMSE: 5.5032
# alpha 0.1일 때 5 폴드 세트의 평균 RMSE: 5.4784
# alpha 0.5일 때 5 폴드 세트의 평균 RMSE: 5.4127
# alpha 1일 때 5 폴드 세트의 평균 RMSE: 5.5216
# alpha 3일 때 5 폴드 세트의 평균 RMSE: 5.9536

# %% [markdown]
# Q8. 'dataset/credit_card.xls' 데이터셋을 불러와서 아래사항을 수행하세요.
# - 전처리 : PAY_0 칼럼을 PAY_1으로 'default payment next month' 칼럼도 'default'로 칼럼명 변경. ID 삭제.
# - heatmap을 이용하여 23개의 속성 데이터간 상관관계 탐색
# - 전체 23개 속성의 1/4 수준인 6개의 PCA 컴포넌트로 분류 예측하고 cv=3으로 교차 검증 수행

# %%
import pandas as pd

df= pd.read_excel('dataset/credit_card.xls',header=1)

df.head(2)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
#
# [2 rows x 25 columns]

# %%
df.rename(columns={'PAY_0':'PAY_1',
          'default payment next month':'default'},inplace=True)
df.drop(['ID'],axis=1,inplace=True)

# %%
X_features = df.drop('default',axis=1)
y_target = df['default']

# %%
import seaborn as sns
cr= df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(cr,annot=True,fmt='.1g')
# Out:
# <AxesSubplot:>

# %%
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

df_scaled= StandardScaler().fit_transform(X_features) 
pca= PCA(n_components=6)
pca.fit(df_scaled)
df_pca= pca.transform(df_scaled)

print('변동성>>', pca.explained_variance_ratio_.round(4))
print('변동성 평균 >> ', pca.explained_variance_ratio_.sum().round(4))
# >> 6개의 컴포넌트로 전체의 변동성을 약 68% 이상 설명 가능
# Out:
# 변동성>> [0.2845 0.1782 0.0674 0.064  0.0446 0.0416]
# 변동성 평균 >>  0.6803

# %%
pca_columns= ['pca_c1','pca_c2', 'pca_c3', 'pca_c4', 'pca_c5', 'pca_c6']
df_Pca= pd.DataFrame(df_pca, columns=pca_columns)
df_Pca['default']= df.default
df_Pca.head(2)
# Out:
#      pca_c1    pca_c2    pca_c3    pca_c4    pca_c5    pca_c6  default
# 0 -1.887962 -0.906109 -0.487732 -0.539998  0.997682  0.044733        1
# 1 -0.764696 -2.109288  1.097356 -0.483459  0.858747 -0.234885        1

# %%
X_features = df_Pca.drop('default',axis=1)
y_target = df_Pca['default']

rf= RandomForestClassifier(n_estimators=300, random_state=156)
scores= cross_val_score(rf,X_features,y_target, scoring='accuracy',cv=3)

print('각 fold별 accuracy >> ',scores)
print('평균 accuracy >> {:.4f}'.format(np.mean(scores)))
# Out:
# 각 fold별 accuracy >>  [0.7914 0.797  0.8027]
# 평균 accuracy >> 0.7970

# %% [markdown]
# Q9. load_iris를 불러와서 군집분석을 수행하세요.
# - 데이터플레임 생성
# - KMeans를 이용하여 군집화한 후 cluster 컬럼 추가

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
iris_df= pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['class']= iris.target
iris_df.head(2)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
#
#    class
# 0      0
# 1      0

# %%
from sklearn.cluster import KMeans

km= KMeans(n_clusters=3,random_state=156)
kmeans= km.fit(iris_df)
# kmeans.labels_

iris_df['cluster']= kmeans.labels_
iris_df.head(2)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
#
#    class  cluster
# 0      0        0
# 1      0        0

# %% [markdown]
# Q10. 'dataset/bike_train.csv'을 불러와서 아래사항을 수행하세요.
# - datetime 타입에서 년, 월, 일, 시간 추출 및 불필요한 컬럼  ['datetime','casual','registered'] 삭제
# - 평가 사용자 함수 작성 및 분류 평가 : RMSLE, RMSE, MAE
# - 종속변수 정규성 개선위한 로그 변환 및 RMSLE, RMSE, MAE 평가
# - 각 Featire의 회귀계수 값 시각화

# %%
bike_df = pd.read_csv('dataset/bike-sharing-demand/train.csv')
bike_df.head(2)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
bike_df['datetime'] = bike_df.datetime.apply(pd.to_datetime)
bike_df.head(2)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40

# %%
bike_df['year'] = bike_df.datetime.apply(lambda x:x.year)
bike_df['month'] = bike_df.datetime.apply(lambda x:x.month)
bike_df['day'] = bike_df.datetime.apply(lambda x:x.day)
bike_df['hour'] = bike_df.datetime.apply(lambda x:x.hour)

# %%
bike_df.drop(['datetime','casual','registered'],axis=1,inplace=True)

# %%
from sklearn.metrics import mean_absolute_error
def rmsle(y,pred):
    log_y= np.log1p(y)
    log_pred = np.log1p(pred)
    squared_error = (log_y - log_pred)**2
    rmsle= np.sqrt(np.mean(squared_error)) 
    return rmsle

# %%
def rmse(y,pred):
    rmse= np.sqrt(mean_squared_error(y,pred))
    return rmse

# %%
def mae(y_test,pred):
    mae= mean_absolute_error(y_test,pred)
    return mae

# %%
def evaluation(y,pred):
    rmsle_ev = rmsle(y,pred)
    rmse_ev = rmse(y,pred)
    mae_ev = mae(y_test,pred)
    print('RMSLE>> {0:.4f}\nRMSE>> {1:.4f}\nMAE>>{2:.4f}'.format(rmsle_ev,rmse_ev,mae_ev))

# %%
y_target = bike_df['count']  
X_features = bike_df.drop(['count'],axis=1) 

X_train, X_test, y_train, y_test = train_test_split(X_features,y_target,
                                                    test_size=0.3,random_state=156)

# %%
lr= LinearRegression()
lr.fit(X_train,y_train)
pred = lr.predict(X_test)
evaluation(y_test,pred)
# Out:
# RMSLE>> 1.1643
# RMSE>> 136.9542
# MAE>>103.1372

# %% [markdown]
# ### 로그변환

# %%
y_target_log = np.log1p(y_target)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_features,y_target_log,
                                                   test_size=0.3, random_state=0)

# %%
lr= LinearRegression()
lr.fit(X_train, y_train)
pred = lr.predict(X_test)

# %%
y_test_exp = np.expm1(y_test)
pred_exp = np.expm1(pred)

evaluation(y_test_exp,pred_exp)
# Out:
# RMSLE>> 1.0168
# RMSE>> 162.5943
# MAE>>149.5956

# %%
coef = pd.Series(lr.coef_ , index=X_features.columns)
coef_sorting = coef.sort_values(ascending=False)

sns.barplot(x=coef_sorting.values, y=coef_sorting.index)
# Out:
# <AxesSubplot:>
