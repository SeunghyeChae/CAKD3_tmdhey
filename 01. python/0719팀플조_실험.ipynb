# %%
# !pip install pyrebase4
# Out:
# Collecting pyrebase4
#   Downloading Pyrebase4-4.5.0-py3-none-any.whl (8.9 kB)
# Collecting requests-toolbelt>=0.7.1
#   Downloading requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
# Collecting pycryptodome>=3.6.4
#   Downloading pycryptodome-3.10.1-cp35-abi3-win_amd64.whl (1.6 MB)
# Collecting gcloud>=0.18.3
#   Downloading gcloud-0.18.3.tar.gz (454 kB)
# Collecting python-jwt>=2.0.1
#   Downloading python_jwt-3.3.0-py2.py3-none-any.whl (6.8 kB)
# Collecting oauth2client>=4.1.2
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: requests>=2.19.1 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from pyrebase4) (2.25.1)
# Requirement already satisfied: httplib2>=0.9.1 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from gcloud>=0.18.3->pyrebase4) (0.19.1)
# Requirement already satisfied: googleapis-common-protos in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from gcloud>=0.18.3->pyrebase4) (1.53.0)
# Requirement already satisfied: protobuf!=3.0.0.b2.post1,>=3.0.0b2 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from gcloud>=0.18.3->pyrebase4) (3.14.0)
# Requirement already satisfied: six in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from gcloud>=0.18.3->pyrebase4) (1.16.0)
# Requirement already satisfied: pyparsing<3,>=2.4.2 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from httplib2>=0.9.1->gcloud>=0.18.3->pyrebase4) (2.4.7)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from oauth2client>=4.1.2->pyrebase4) (4.7.2)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from oauth2client>=4.1.2->pyrebase4) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from oauth2client>=4.1.2->pyrebase4) (0.2.8)
# Collecting jwcrypto>=0.8
#   Downloading jwcrypto-0.9.1-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: cryptography>=2.3 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from jwcrypto>=0.8->python-jwt>=2.0.1->pyrebase4) (3.4.7)
# Collecting deprecated
#   Downloading Deprecated-1.2.12-py2.py3-none-any.whl (9.5 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from cryptography>=2.3->jwcrypto>=0.8->python-jwt>=2.0.1->pyrebase4) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from cffi>=1.12->cryptography>=2.3->jwcrypto>=0.8->python-jwt>=2.0.1->pyrebase4) (2.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from requests>=2.19.1->pyrebase4) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from requests>=2.19.1->pyrebase4) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from requests>=2.19.1->pyrebase4) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from requests>=2.19.1->pyrebase4) (3.0.4)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\sh\anaconda3\envs\cakd3\lib\site-packages (from deprecated->jwcrypto>=0.8->python-jwt>=2.0.1->pyrebase4) (1.12.1)
# Building wheels for collected packages: gcloud
#   Building wheel for gcloud (setup.py): started
#   Building wheel for gcloud (setup.py): finished with status 'done'
#   Created wheel for gcloud: filename=gcloud-0.18.3-py3-none-any.whl size=602937 sha256=df518b0e836af6fe2cef0b6b10242c10170ba2687e31b690f59cab1719f1e6a5
#   Stored in directory: c:\users\sh\appdata\local\pip\cache\wheels\86\05\94\4ad6324debd4e3edba7fdf252f1ff2d2aba09673a794e67a27
# Successfully built gcloud
# Installing collected packages: deprecated, oauth2client, jwcrypto, requests-toolbelt, python-jwt, pycryptodome, gcloud, pyrebase4
# Successfully installed deprecated-1.2.12 gcloud-0.18.3 jwcrypto-0.9.1 oauth2client-4.1.3 pycryptodome-3.10.1 pyrebase4-4.5.0 python-jwt-3.3.0 requests-toolbelt-0.9.1

# %%
# ################### 사용자 database 에 추가하기 함수(회원가입) ###################

# # 추가하는 방식은    email   password   wanttags  sentvideo
# import pyrebase
# def useradd():
#     config = {
#         'apiKey': "AIzaSyBh3PyZNCdyd2mh12YcXe8Af7m6rl4QzSs",
#         'authDomain': "studygroup-playllist.firebaseapp.com",
#         'databaseURL': "https://studygroup-playllist-default-rtdb.firebaseio.com",
#         'projectId': "studygroup-playllist",
#         'storageBucket': "studygroup-playllist.appspot.com",
#         'messagingSenderId': "181894569806",
#         'appId': "1:181894569806:web:917dea0dd0859dd764c81f",
#         'measurementId': "G-HC5K5C0C2D"
#       };

#     firebase = pyrebase.initialize_app(config)
#     database = firebase.database()

#     # 다음 사용자가 부여받을 ID 고유번호  
#     userID=database.child("users_nextID").get().val()
#     try:
#         emailexisting=[]
#         for i in range(1,userID):
#             emailexisting.append(database.child('users').child(i).child('email').get().val())
#     except:
#         userID=1
    
            
#     # 존재하는

# %%
# ##### ★★★★★★★★★★
# ## 최종가입@@@@@@@@@@


# ## 사용자 database 에 추가하기 함수
# # 추가하는 방식은    email   password   wanttags  sentvideo
# import pyrebase
# def useradd():
#     config = {
#         'apiKey': "AIzaSyBh3PyZNCdyd2mh12YcXe8Af7m6rl4QzSs",
#         'authDomain': "studygroup-playllist.firebaseapp.com",
#         'databaseURL': "https://studygroup-playllist-default-rtdb.firebaseio.com",
#         'projectId': "studygroup-playllist",
#         'storageBucket': "studygroup-playllist.appspot.com",
#         'messagingSenderId': "181894569806",
#         'appId': "1:181894569806:web:917dea0dd0859dd764c81f",
#         'measurementId': "G-HC5K5C0C2D"
#       };

#     firebase = pyrebase.initialize_app(config)
#     database = firebase.database()

#     # 다음 사용자가 부여받을 ID 고유번호  
#     userID=database.child("users_nextID").get().val()
#     try:
#         emailexisting=[]
#         for i in range(1,userID):
#             emailexisting.append(database.child('users').child(i).child('email').get().val())
#     except:
#         userID=1
    
            
#     # 존재하는 이미 data

# %%
################### 사용자 database 에 추가하기 함수(회원가입) ###################

# 추가하는 방식은    email   password   wanttags  sentvideo
import pyrebase
def useradd():
    config = {
        'apiKey': "AIzaSyBh3PyZNCdyd2mh12YcXe8Af7m6rl4QzSs",
        'authDomain': "studygroup-playllist.firebaseapp.com",
        'databaseURL': "https://studygroup-playllist-default-rtdb.firebaseio.com",
        'projectId': "studygroup-playllist",
        'storageBucket': "studygroup-playllist.appspot.com",
        'messagingSenderId': "181894569806",
        'appId': "1:181894569806:web:917dea0dd0859dd764c81f",
        'measurementId': "G-HC5K5C0C2D"
      };

    firebase = pyrebase.initialize_app(config)
    database = firebase.database()

    # 다음 사용자가 부여받을 ID 고유번호  
    userID=database.child("users_nextID").get().val()
    try:
        emailexisting=[]
        for i in range(1,userID):
            emailexisting.append(database.child('users').child(i).child('email').get().val())
    except:
        userID=1
    
            
    # 존재하는 이미 database에 존재하는 email 불러오기

    print("정보를 잘못 입력시, 'Name :' 나올때까지 enter 입력")
    while 1:
        name = input("Name : ")
        
        
        while 1:
            email = input("ID : ")
            if email in emailexisting:
                print("이미 존재하는 아이디입니다. 이메일을 다시 입력해주세요.")
            else:
                break
        
        pw = input("Password : ")
        
        if email=='' or pw=='':
            print("요구하는 정보를 다 입력해주세요.")
        else:
            break
    
    
    while 1:
        ### 나중에 업데이트 : database 확인해서 존재하는 모든 tags 고를 수 있게 만들기
        tags = input("관심있는 category를 골라주세요. (최소1개)\n1) 'python'\n2) 'crawling'\n3) 'selenium'\n4) 'pandas'\n5) 'dataframe'\n6) 'machinelearning'\n7) 'requests'\n\n입력예시 -> 1342   >"  )
        tagslists=["python",'crawling','selenium','pandas','dataframe','machinelearning','requests']
        tagsindexlist = list(set(list(tags)))

        tagschoice=[]
        for index in tagsindexlist:
            
            # try 는 혹시나 index 밖의 값입력시
            try:
                index=int(index)
                if index-1<0:
                    int('error')
                tagschoice.append(tagslists[index-1])
            except:
                print('1부터 7 숫자 조합을 제외한 숫자는 제외합니다.')
        
        if tagschoice!=[]:
            tagstr=''
            for i in tagschoice:
                tagstr+=i+', '
            print(f"{tagstr}를 관심 category로 지정합니다.")
            ## 나중에 category 수정하는 것도 만들기. 앱에서 로그인후 프로필 수정 페이지 만들기
            break
        else:
            pass
    
    userinfo = {'userID':userID,'userName':name,"email":email,"pw":pw,"tags":tagschoice}
    
    config = {
        'apiKey': "AIzaSyBh3PyZNCdyd2mh12YcXe8Af7m6rl4QzSs",
        'authDomain': "studygroup-playllist.firebaseapp.com",
        'databaseURL': "https://studygroup-playllist-default-rtdb.firebaseio.com",
        'projectId': "studygroup-playllist",
        'storageBucket': "studygroup-playllist.appspot.com",
        'messagingSenderId': "181894569806",
        'appId': "1:181894569806:web:917dea0dd0859dd764c81f",
        'measurementId': "G-HC5K5C0C2D"
      };


    firebase = pyrebase.initialize_app(config)
    database = firebase.database()

    database.child("users").child(userID).set(userinfo)
    database.child("users_nextID").set(userID+1)
    print("Database에 추가완료")
### login 되면 


def login(checkID , checkpw):
    config = {
        'apiKey': "AIzaSyBh3PyZNCdyd2mh12YcXe8Af7m6rl4QzSs",
        'authDomain': "studygroup-playllist.firebaseapp.com",
        'databaseURL': "https://studygroup-playllist-default-rtdb.firebaseio.com",
        'projectId': "studygroup-playllist",
        'storageBucket': "studygroup-playllist.appspot.com",
        'messagingSenderId': "181894569806",
        'appId': "1:181894569806:web:917dea0dd0859dd764c81f",
        'measurementId': "G-HC5K5C0C2D"
      };

    firebase = pyrebase.initialize_app(config)
    database = firebase.database()

    users=database.child("users").get().val()
#     userlist.remove(None)
    userlist=users[1:]
    for i in userlist:
        ID=i['email']
        pw = i['pw']
        if ID==checkID:
            if checkpw==pw:
                return True
            else:
                pass
        else:
            pass
    return False

# %%
while 1:
    ID = input("Login ID  > ")
    pw = input("Login Password  > ")
    check=login(ID,pw)
    if check==False:
        print("< 로그인 실패 >")
        addcheck=input("1) 다시 로그인 시도\n2) 회원가입\n3) 종료\n > ")
        if addcheck=='1':
            pass
        elif addcheck=='2':
            useradd()
        else:
            break
            
        
        pass
    else:
        print('< 로그인 되었습니다 >')
        break
# Out:
# Login ID  > tmdhey
# Login Password  > 0312
# < 로그인 되었습니다 >

# %%
import pyrebase

config = {
        'apiKey': "AIzaSyBh3PyZNCdyd2mh12YcXe8Af7m6rl4QzSs",
        'authDomain': "studygroup-playllist.firebaseapp.com",
        'databaseURL': "https://studygroup-playllist-default-rtdb.firebaseio.com",
        'projectId': "studygroup-playllist",
        'storageBucket': "studygroup-playllist.appspot.com",
        'messagingSenderId': "181894569806",
        'appId': "1:181894569806:web:917dea0dd0859dd764c81f",
        'measurementId': "G-HC5K5C0C2D"
      };

firebase = pyrebase.initialize_app(config)
database = firebase.database()

users=database.child("users").get().val()
#     userlist.remove(None)
userlist=users[1:]
print("< 현재 회원가입된 인원 아이디 >")
for i,name in enumerate(userlist):
    name=name['userName']
    print(f"{i+1}) {name}")
# Out:
# < 현재 회원가입된 인원 아이디 >
# 1) 권준기
# 2) 최한결
# 3) 조현정
# 4) 이재원
# 5) 박기범
# 6) 최윤진
# 7) 우동주
# 8) 이민찬
# 9) 되남?
# 10) 하도원
# 11) 승해
# 12) 하도원
# 13) lim
# 14) 정하림
# 15) 1
